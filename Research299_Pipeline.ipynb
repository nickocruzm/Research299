# %% [markdown]
# <a href="https://colab.research.google.com/github/nickocruzm/Research299/blob/main/Research299_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Imports

# %%
# %%capture
# !pip install diffusers==0.32.2
# !pip install transformers==4.49
# !pip install --upgrade peft
#!pip install peft==0.17

# !pip install open_clip_torch
# !pip install accelerate
# !pip install -q kaggle
# !pip install torch-fidelity

from accelerate import Accelerator

from torch_fidelity import calculate_metrics
import math
import json
import random
import argparse
import itertools
import time
from diffusers.pipelines.stable_diffusion import safety_checker

from diffusers import (
    AutoencoderKL,
    DDPMScheduler,
    DDIMScheduler,
    DPMSolverMultistepScheduler,
    EulerDiscreteScheduler,
    EDMEulerScheduler,
    HeunDiscreteScheduler,
    LMSDiscreteScheduler,
    PNDMScheduler,
    StableDiffusionPipeline,
    UNet2DConditionModel,
    UniPCMultistepScheduler
)

from typing import Optional, List
from transformers import AutoTokenizer, CLIPTextModel, CLIPTokenizer
from PIL import Image
from pycocotools.coco import COCO

import pandas as pd

from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch import nn
import torch.nn.functional as F

import os
import warnings

import torch
from torch.utils.data import DataLoader
from transformers import CLIPProcessor, CLIPModel
from torchvision import models, transforms
from PIL import Image
import torch.nn as nn


from google.colab import userdata, drive
warnings.filterwarnings('ignore')
drive.mount('/content/drive')

userdata.get("HF_TOKEN")
os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %% [markdown]
# ### CONSTANTS

# %%
# Google Drive Directories
PROJECT_DIR = "/content/drive/MyDrive/Research299"
COCO_DIR = os.path.join(PROJECT_DIR, "COCO")
RAW_COCO_DIR = os.path.join(COCO_DIR, "raw")
GENERATED_COCO_DIR = os.path.join(COCO_DIR, "generated")
DATA_DIR = os.path.join(COCO_DIR, "data")

# captions file
COCO_CAPTIONS_PATH = os.path.join(COCO_DIR, "test_captions.csv")

# FID file's path
FID_PATH = os.path.join(DATA_DIR,'fid_scores.csv')
CLIP_PATH = os.path.join(DATA_DIR,'clip_scores.csv')

# MODEL ID's
SD_MODEL_ID = "runwayml/stable-diffusion-v1-5"
CLIP_MODEL_ID = "openai/clip-vit-base-patch32"

# Inception Model's Weights used to calculate FID
INCEPT_WEIGHTS = "IMAGENET1K_V1"

# Diffusion Model's Parameters
SD_PARAMS = {
    "num_inference_steps": 20
}

# pipeline's params
BATCH_SIZE = 5

# minimumum amount of images needed to be generated by scheduler to evaluate
COCO_MIN_IMAGE_COUNT = 4500

# Hugging face scheduler labels
SCHEDULER_LABELS = ["ddpm", "pndm", "ddim", "unipc", "lms", "heun", "eds", "edm"]

# %% [markdown]
# ### Utilities

# %%
from pathlib import Path
import pandas as pd

def diff_folders(dir1, dir2):
    """
        finds the difference between two directories.
        Used when ensuring all images are generated from real images.
    """
    files1 = {p.name for p in Path(dir1).iterdir() if p.is_file()}
    files2 = {p.name for p in Path(dir2).iterdir() if p.is_file()}

    only_in_dir1 = files1 - files2
    only_in_dir2 = files2 - files1

    return only_in_dir1, only_in_dir2

def count_images(img_dir:str, output:bool=False):
    """
        Count the number of images within a dir.
        Output is optional
    """
    imgs = {".jpg", ".jpeg", ".png"}
    count = sum(1 for p in Path(img_dir).iterdir() if p.suffix.lower() in imgs)
    s = os.path.basename(os.path.normpath(img_dir))

    if output: print(f"{s}:\t{count}")

    return count

def check_image_dimensions(directory_path, sched_lbl=None):
    """
    Checks all image files in a given directory for uniform dimensions.
    """
    if sched_lbl is None: sched_lbl = "unkown"

    if not os.path.isdir(directory_path):
        print(f"Directory '{directory_path}' does not exist.")
        return

    print(f"\nChecking image dimensions in '{sched_lbl}' \t full path: '{directory_path}')...")
    image_sizes = set()
    image_count = 0

    for f in os.listdir(directory_path):

        if not f.lower().endswith(('.png', '.jpg', '.jpeg')): continue

        image_count += 1
        img_path = os.path.join(directory_path, f)
        try:
            with Image.open(img_path) as img:
                image_sizes.add(img.size)
        except Exception as e:
            print(f"Error opening {img_path}: {e}")

    if image_count == 0:
        print(f"No images found in '{sched_lbl}'.")
    elif len(image_sizes) == 1:
        print(f"All {image_count} images in '{sched_lbl}' have uniform dimensions: {list(image_sizes)[0]}")
    else:
        print(f"Images in '{sched_lbl}' have varying dimensions: {image_sizes}")

def reset_generated_images():
    """
        Removes generated images from generated directory
        GENERATED_COCO_DIR: PROJECT_DIR/Research299/COCO/generated
        assumes the directory is already created.
    """
    img_types = ['.jpg', '.png', '.jpeg']
    for img in os.listdir(GENERATED_COCO_DIR):
        pth = os.path.join(GENERATED_COCO_DIR, img)
        os.unlink(pth)
    generated_images_count = sum(1 for p in Path(GENERATED_COCO_DIR).iterdir() if p.suffix.lower() in img_types)
    print(f'images found in generated directory: {generated_images_count}')

def setup_device():
    if torch.cuda.is_available():
        device_str = "cuda"
    elif torch.backends.mps.is_available():
        device_str = "mps"
    else:
        device_str = "cpu"
    print(f'device: {device_str}')
    return torch.device(device_str)

def remove_duplicates_by_scheduler(df, sched):
    grouped = df[df['scheduler'] == sched]
    print(f'old shape: {grouped.shape}')
    dups = grouped[grouped.duplicated(subset=['image_id', 'scheduler'], keep=False)]
    print(f'new shape: {dups.shape}')
    return dups

def get_real_tensors(incept_model):
    global DATA_DIR
    path1 = f'{DATA_DIR}/mu_real.pt'
    path2 = f'{DATA_DIR}/sigma_real.pt'

    if not (os.path.exists(path1) and os.path.exists(path2)):
        raw_image_paths = [
            os.path.join(RAW_COCO_DIR, f) for f in os.listdir(RAW_COCO_DIR) if os.path.isfile(os.path.join(RAW_COCO_DIR, f))
        ]
        mu_real, sigma_real = compute_stats(raw_image_paths, incept_model, device=device, batch_size=5)

        torch.save(mu_real, os.path.join(data_dir, "mu_real.pt"))
        torch.save(sigma_real, os.path.join(data_dir, "sigma_real.pt"))
        print(f"mu_real and sigma_real saved to {data_dir}")

    else:
        mu_real = torch.load(path1)
        sigma_real = torch.load(path2)

        print(f"mu_real and sigma_real loaded from {DATA_DIR}")

    return mu_real, sigma_real

def collect_captions(src_dir, captions_dir:str, captions:pd.DataFrame=None):
    """
        iterates through the RAW/real image file names strips the filenames
        to the image id and returns a dictionary of {image_id: caption}

        Grabs the first caption of the multiple captions in the list.
    """

    if captions is None: captions = pd.read_csv(captions_dir)

    gen_img_df = {}
    for img in os.listdir(src_dir):
        # convert image's file_name into an image_id.
        try:
            img_id = int(img.lstrip('0').removesuffix('.jpg'))
        except Exception as e:
            print("file is not image type")

        # locate image caption and store the first caption of the multiple given.
        prompt = captions[captions['image_id'] == img_id]['caption'].tolist()[0]

        if img_id in gen_img_df.keys():
            print("conflicting keys: ", img_id)
            continue
        else:
            gen_img_df[img_id] = prompt

    return gen_img_df

def compute_FID(real_dir, generated_dir, model, fid_scores, scheduler="ddpm",  mu_real=None, sigma_real=None):

    if mu_real is None and sigma_real is None:

        raw_image_paths = [
            os.path.join(real_dir, f) for f in os.listdir(real_dir) if os.path.isfile(os.path.join(real_dir, f))
        ]

        mu_real, sigma_real = compute_stats(raw_image_paths, model, device="cuda", batch_size=32)



    generated_image_paths = [
        os.path.join(generated_dir,f) for f in os.listdir(generated_dir)
        if os.path.isfile(os.path.join(generated_dir, f))
    ]

    fid_dict_key = f'{scheduler}_{len(generated_image_paths)}'

    if fid_dict_key not in fid_scores.keys():

        mu_gen, sigma_gen = compute_stats(generated_image_paths, model, device="cuda", batch_size=32)
        fid_score = frechet_distance(mu_gen, sigma_gen, mu_real, sigma_real)

        fid_scores[fid_dict_key] = fid_score
        print(f'FID score for {s}: {fid_score['mean']}')

def frechet_distance(mu1, sigma1, mu2, sigma2, eps: float = 1e-6) -> float:
    """
    FID = ||mu1-mu2||^2 + Tr(sigma1 + sigma2 - 2*sqrt(sigma1*sigma2))
    Uses stable symmetric form:
      sqrt(sigma1*sigma2) = sqrt( sqrt(sigma1) * sigma2 * sqrt(sigma1) )
    """
    mu1, mu2 = mu1.flatten(), mu2.flatten()
    diff = mu1 - mu2

    s1_sqrt = matrix_sqrt_psd(sigma1, eps=eps)
    middle = s1_sqrt @ sigma2 @ s1_sqrt
    middle_sqrt = matrix_sqrt_psd(middle, eps=eps)

    fid = diff.dot(diff) + torch.trace(sigma1) + torch.trace(sigma2) - 2.0 * torch.trace(middle_sqrt)
    return float(fid.item())

def compute_stats(image_paths, model, device="cuda", batch_size=BATCH_SIZE, num_workers=0):
    tfm = transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ])

    feats = []
    batch_number = 0
    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i+batch_size]
        imgs = []
        for p in batch_paths:
            img = Image.open(p).convert("RGB")
            imgs.append(tfm(img))

        x = torch.stack(imgs, dim=0).to(device)
        with torch.no_grad():
            f = model(x)  # (B, 2048)
        feats.append(f.detach().cpu())
        batch_number += 1

    feats = torch.cat(feats, dim=0)  # (N, 2048)
    mu = feats.mean(dim=0)
    sigma = cov_matrix(feats)
    return mu, sigma

def cov_matrix(X: torch.Tensor) -> torch.Tensor:
    """
    X: (N, D)
    returns: (D, D) covariance
    """
    X = X - X.mean(dim=0, keepdim=True)
    N = X.shape[0]
    return (X.T @ X) / (N - 1)

def matrix_sqrt_psd(A: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
    """
    Symmetric PSD matrix square root using eigendecomposition.
    """
    A = (A + A.T) * 0.5  # enforce symmetry
    evals, evecs = torch.linalg.eigh(A)
    evals = torch.clamp(evals, min=eps)
    sqrt_evals = torch.sqrt(evals)
    return (evecs * sqrt_evals.unsqueeze(0)) @ evecs.T

def compute_CLIP_scores(dir, schedule, image_ids, clip_captions, device):
    G = []
    for id in image_ids:
        path = f'{dir}/{id}.png'
        img = Image.open(path).convert("RGB")
        G.append(path)

    inputs = clip_processor(
        text=clip_captions,
        images=G,
        return_tensors="pt",
        padding=True
    ).to(device)

    outputs = clip_model(**inputs)
    scores = torch.diag(outputs.logits_per_image).detach().cpu()
    scores = scores.tolist()

    return pd.DataFrame({
        "image_id":image_ids,
        "scheduler":[schedule] * len(image_ids),
        "clip_score": scores
    })

def get_schedulers_status():
    """
        Determine which schedulers no longer need images generated for.
        Gets the count of images generated in each directory
    """
    global SCHEDULER_LABELS
    COCO_MIN_IMAGE_COUNT = 4500

    if SCHEDULER_LABELS is None:
        SCHEDULER_LABELS = ["ddpm", "pndm", "ddim", "unipc", "lms", "heun", "eds", "edm"]

    images_generated = {s:0 for s in SCHEDULER_LABELS}
    generated_complete = {s:False for s in SCHEDULER_LABELS}

    for s in SCHEDULER_LABELS:
        dir = GENERATED_COCO_DIR + f'/{s}'

        os.makedirs(dir, exist_ok=True)

        c = count_images(dir, output=True)

        if c > COCO_MIN_IMAGE_COUNT:
            generated_complete[s] = True
            images_generated[s] = c

    return generated_complete, images_generated

# %% [markdown]
# ## COCODataset Class

# %%
from torch.utils.data import Dataset
import torch

class COCODataset(Dataset):
    def __init__(self, image_dir, image_ids, captions):
        self.image_dir = image_dir
        self.image_ids = image_ids
        self.captions = captions


    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_id = self.image_ids[idx]


        caption = self.captions[img_id]

        return {
            "image_id": img_id,
            "caption": caption
        }

# %% [markdown]
# ## Initialization

# %%
device = setup_device()

pipe = StableDiffusionPipeline.from_pretrained(
    SD_MODEL_ID,
    torch_dtype=torch.float16,
    num_images_per_prompt=1,
    num_inference_steps = SD_PARAMS['num_inference_steps']
).to(device)

clip_model = CLIPModel.from_pretrained(CLIP_MODEL_ID).to(device)
clip_processor = CLIPProcessor.from_pretrained(CLIP_MODEL_ID)


# dictionary with {image_id: caption}
captions_dict = collect_captions(RAW_COCO_DIR, COCO_CAPTIONS_PATH)
# list of image_ids from captions
image_ids = list(int(k) for k in captions_dict.keys())
image_ids = sorted(image_ids)

raw_dataset = COCODataset(
    RAW_COCO_DIR,
    image_ids,
    captions_dict
)
# Out:
# device: cuda
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# file is not image type
# conflicting keys:  573258

# %% [markdown]
# ### Scheduler Dictionary
# all schedulers are imported from diffusers library

# %% [markdown]
# count the number of images generated by each scheduler, sort keys by image count in ascending order to start generation of images using the scheduler with the least amount of images generated.

# %%
from pathlib import Path
import os

huggingFace_schedulers = {
    "ddpm":DDPMScheduler,
    "pndm":PNDMScheduler,
    "ddim":DDIMScheduler,
    "unipc":UniPCMultistepScheduler,
    "lms":LMSDiscreteScheduler,
    "heun":HeunDiscreteScheduler,
    "eds":EulerDiscreteScheduler,
    "edm":EDMEulerScheduler
}

generation_completed, images_generated = get_schedulers_status()
# sort schedulers in ascending order by number of images already generated
sorted_scheduler_keys = [k for k,_ in sorted(images_generated.items(), key=lambda x: x[1])]
# start with scheduler that has the smallest count of images generated
schedulers = {k: huggingFace_schedulers[k] for k in sorted_scheduler_keys}
# Out:
# ddpm:	5000
# pndm:	5000
# ddim:	5000
# unipc:	5000
# lms:	5000
# heun:	4998
# eds:	4980
# edm:	5000

# %% [markdown]
# Set up the `clip_scores.csv` file.

# %%
# Check if the CSV file exists and is not empty
if os.path.exists(CLIP_PATH) and os.path.getsize(CLIP_PATH) > 0:
    clip_df = pd.read_csv(CLIP_PATH)
else:
    # If the file doesn't exist or is empty, create an empty DataFrame with headers
    clip_df = pd.DataFrame(columns=['image_id', 'scheduler', 'clip_score'])
    # Save the empty DataFrame with headers to the file
    clip_df.to_csv(CLIP_PATH, index=False) # Save with header to prevent future EmptyDataError

print(f'original CLIP scores: {clip_df.shape}')
# Out:
# original CLIP scores: (38210, 3)

# %% [markdown]
# #### Rough patch removing duplicates

# %%
clip_df = pd.read_csv(CLIP_PATH)
unique_df = clip_df.drop_duplicates(subset=["image_id", "scheduler"], keep="first")
labels = [x for x in schedulers.keys()]
count = 0
for s in labels:
    instances = unique_df.loc[unique_df['scheduler'] == s].shape[0]
    print(f'{s}: {unique_df.loc[unique_df['scheduler'] == s].shape}')
    count += instances
print(f'total: {count}')

unique_df.to_csv(CLIP_PATH, index=False)

# No shape should have greater than 5000 rows
print(f'{unique_df.shape}')
# Out:
# eds: (3500, 3)
# heun: (3597, 3)
# ddpm: (4496, 3)
# pndm: (4017, 3)
# ddim: (3997, 3)
# unipc: (5000, 3)
# lms: (4792, 3)
# edm: (5000, 3)
# total: 34399
# duplicates removed: (34399, 3)

# %% [markdown]
# ## Main Inference Loop

# %% [markdown]
# - Images Generated are saved to drive
# - Clip scores computes are saved to .csv file.
#
# - Inference loop only generates new image and computes new clip scores.
#     - If the clip scores or images generated are found in csv then they are not added to the batch.
#
#
# - will switch schedulers every N batches.
#
# - FID scores are computed after the inference loop finishes.

# %%
clip_df = pd.read_csv(CLIP_PATH)
print(f'CLIP SCORES: {clip_df.shape}')
clip_df.set_index(['image_id','scheduler'], inplace=True)

for scheduler_lbl, Sched in schedulers.items():
    print(f'SCHEDULER: {scheduler_lbl}')
    # switch scheduler
    pipe.scheduler = Sched.from_config(pipe.scheduler.config)

    # directory with real images
    real_dir = RAW_COCO_DIR

    # directory with generated images
    generated_dir = os.path.join(GENERATED_COCO_DIR, scheduler_lbl)

    # directory with scores saved csv files
    data_dir = os.path.join(COCO_DIR,'data')

    # creates the directories if it doesn't exist, else does nothing
    os.makedirs(real_dir, exist_ok=True)
    os.makedirs(generated_dir, exist_ok=True)
    os.makedirs(data_dir, exist_ok=True)

    # set loader
    loader = DataLoader(
        raw_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    # reset after switching schedulers
    batch_idx = 1

    # will only count the newly generated images
    totals ={
        'images_generated':0,
        'clips_computed': 0,
    }

    with torch.no_grad():
        for batch in loader:
            # get captions and image_ids from batch
            captions, img_ids = batch["caption"], batch["image_id"].tolist()

            # for each batch reset generative caps and generative ids.
            gen_caps, gen_ids = [],[]
            clip_caps, clip_ids = [],[]

            # iterate through batch and collect unused captions and ids
            for cap, img_id in zip(captions, img_ids):

                outpath = f'{generated_dir}/{img_id}.png'

                # if the file doesn't exist then we haven't generated it yet
                if not os.path.exists(outpath):
                    gen_caps.append(cap)
                    gen_ids.append(img_id)

                # if the id and scheduler is not in the index then we have not yet generated a clip score
                if (img_id, scheduler_lbl) not in clip_df.index:
                    print(f'CLIP: {img_id}, {scheduler_lbl}')
                    clip_ids.append(img_id)
                    clip_caps.append(cap)



            if gen_ids:
                generated_images = pipe(gen_caps, num_inference_steps=20).images
                images_generated[scheduler_lbl] += len(generated_images)
                totals['images_generated'] += len(generated_images)
                print(f'\tGENERATED {len(generated_images)} IMAGES')

                # Save generated images
                for img, gid in zip(generated_images, gen_ids):
                    out_path = f'{generated_dir}/{gid}.png'
                    img.save(out_path)

            if clip_ids:

                totals['clips_computed'] += len(clip_ids)
                scores = compute_CLIP_scores(generated_dir, scheduler_lbl, clip_ids, clip_caps, device)
                print(f'\tCOMPUTED {len(clip_ids)} CLIP SCORES')
                indexed_scores = scores.set_index(['image_id','scheduler'], inplace=False)
                clip_df = pd.concat([clip_df,indexed_scores])

                scores.to_csv(
                    CLIP_PATH,
                    mode='a',
                    index=False,
                    header= not os.path.exists(CLIP_PATH)
                )



            if batch_idx % 10 == 0:
                print(f'scheduler name: {scheduler_lbl}, batch_idx: {batch_idx}')

            if batch_idx % 100 == 0:
                break

            if clip_ids or gen_ids:
                batch_idx += 1
# Out:
# CLIP SCORES: (34429, 3)
# SCHEDULER: eds
# CLIP: 289594, eds
# CLIP: 289659, eds
# CLIP: 289702, eds
# CLIP: 289741, eds
# CLIP: 289938, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 289960, eds
# CLIP: 289992, eds
# CLIP: 290081, eds
# CLIP: 290163, eds
# CLIP: 290179, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290248, eds
# CLIP: 290293, eds
# CLIP: 290592, eds
# CLIP: 290619, eds
# CLIP: 290768, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290771, eds
# CLIP: 290833, eds
# CLIP: 290843, eds
# CLIP: 291490, eds
# CLIP: 291551, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 291619, eds
# CLIP: 291634, eds
# CLIP: 291664, eds
# CLIP: 291791, eds
# CLIP: 291861, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292005, eds
# CLIP: 292024, eds
# CLIP: 292060, eds
# CLIP: 292082, eds
# CLIP: 292155, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292225, eds
# CLIP: 292236, eds
# CLIP: 292330, eds
# CLIP: 292415, eds
# CLIP: 292446, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292456, eds
# CLIP: 292488, eds
# CLIP: 292908, eds
# CLIP: 292997, eds
# CLIP: 293044, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293071, eds
# CLIP: 293200, eds
# CLIP: 293245, eds
# CLIP: 293300, eds
# CLIP: 293324, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293390, eds
# CLIP: 293474, eds
# CLIP: 293625, eds
# CLIP: 293794, eds
# CLIP: 293804, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 10
# CLIP: 293858, eds
# CLIP: 294162, eds
# CLIP: 294163, eds
# CLIP: 294350, eds
# CLIP: 294695, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 294783, eds
# CLIP: 294831, eds
# CLIP: 294855, eds
# CLIP: 295138, eds
# CLIP: 295231, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295316, eds
# CLIP: 295420, eds
# CLIP: 295478, eds
# CLIP: 295713, eds
# CLIP: 295797, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295809, eds
# CLIP: 296222, eds
# CLIP: 296224, eds
# CLIP: 296231, eds
# CLIP: 296284, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 296317, eds
# CLIP: 296634, eds
# CLIP: 296649, eds
# CLIP: 296657, eds
# CLIP: 296969, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297022, eds
# CLIP: 297084, eds
# CLIP: 297085, eds
# CLIP: 297147, eds
# CLIP: 297343, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297353, eds
# CLIP: 297396, eds
# CLIP: 297427, eds
# CLIP: 297562, eds
# CLIP: 297578, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297595, eds
# CLIP: 297681, eds
# CLIP: 297698, eds
# CLIP: 297830, eds
# CLIP: 298251, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 298396, eds
# CLIP: 298697, eds
# CLIP: 298738, eds
# CLIP: 298904, eds
# CLIP: 298994, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 299355, eds
# CLIP: 299553, eds
# CLIP: 299609, eds
# CLIP: 299720, eds
# CLIP: 299887, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 20
# CLIP: 300039, eds
# CLIP: 300155, eds
# CLIP: 300233, eds
# CLIP: 300276, eds
# CLIP: 300341, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 300659, eds
# CLIP: 300842, eds
# CLIP: 300913, eds
# CLIP: 301061, eds
# CLIP: 301135, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301376, eds
# CLIP: 301421, eds
# CLIP: 301563, eds
# CLIP: 301718, eds
# CLIP: 301867, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301981, eds
# CLIP: 302030, eds
# CLIP: 302107, eds
# CLIP: 302165, eds
# CLIP: 302452, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 302536, eds
# CLIP: 302760, eds
# CLIP: 302882, eds
# CLIP: 302990, eds
# CLIP: 303305, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303499, eds
# CLIP: 303566, eds
# CLIP: 303653, eds
# CLIP: 303713, eds
# CLIP: 303818, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303863, eds
# CLIP: 303893, eds
# CLIP: 303908, eds
# CLIP: 304180, eds
# CLIP: 304291, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304365, eds
# CLIP: 304396, eds
# CLIP: 304404, eds
# CLIP: 304545, eds
# CLIP: 304560, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304812, eds
# CLIP: 304817, eds
# CLIP: 304984, eds
# CLIP: 305309, eds
# CLIP: 305317, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 305343, eds
# CLIP: 305609, eds
# CLIP: 305695, eds
# CLIP: 306136, eds
# CLIP: 306139, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 30
# CLIP: 306437, eds
# CLIP: 306582, eds
# CLIP: 306700, eds
# CLIP: 306733, eds
# CLIP: 306893, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 307074, eds
# CLIP: 307145, eds
# CLIP: 307172, eds
# CLIP: 307598, eds
# CLIP: 307658, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308165, eds
# CLIP: 308193, eds
# CLIP: 308328, eds
# CLIP: 308391, eds
# CLIP: 308394, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308430, eds
# CLIP: 308466, eds
# CLIP: 308476, eds
# CLIP: 308531, eds
# CLIP: 308545, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308587, eds
# CLIP: 308631, eds
# CLIP: 308753, eds
# CLIP: 308793, eds
# CLIP: 308799, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 309173, eds
# CLIP: 309391, eds
# CLIP: 309452, eds
# CLIP: 309467, eds
# CLIP: 309484, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 309495, eds
# CLIP: 309655, eds
# CLIP: 309678, eds
# CLIP: 309938, eds
# CLIP: 309964, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 310072, eds
# CLIP: 310200, eds
# CLIP: 310622, eds
# CLIP: 310862, eds
# CLIP: 310980, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311002, eds
# CLIP: 311081, eds
# CLIP: 311180, eds
# CLIP: 311190, eds
# CLIP: 311295, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311303, eds
# CLIP: 311392, eds
# CLIP: 311394, eds
# CLIP: 311518, eds
# CLIP: 311789, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 40
# CLIP: 311883, eds
# CLIP: 311909, eds
# CLIP: 311928, eds
# CLIP: 311950, eds
# CLIP: 312192, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312213, eds
# CLIP: 312237, eds
# CLIP: 312263, eds
# CLIP: 312278, eds
# CLIP: 312340, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312406, eds
# CLIP: 312421, eds
# CLIP: 312489, eds
# CLIP: 312549, eds
# CLIP: 312552, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312586, eds
# CLIP: 312720, eds
# CLIP: 313034, eds
# CLIP: 313130, eds
# CLIP: 313182, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 313454, eds
# CLIP: 313562, eds
# CLIP: 313588, eds
# CLIP: 313783, eds
# CLIP: 314034, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314177, eds
# CLIP: 314182, eds
# CLIP: 314251, eds
# CLIP: 314264, eds
# CLIP: 314294, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314541, eds
# CLIP: 314709, eds
# CLIP: 314914, eds
# CLIP: 315001, eds
# CLIP: 315187, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 315219, eds
# CLIP: 315257, eds
# CLIP: 315450, eds
# CLIP: 315492, eds
# CLIP: 316015, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 316054, eds
# CLIP: 316404, eds
# CLIP: 316666, eds
# CLIP: 317024, eds
# CLIP: 317433, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 317999, eds
# CLIP: 318080, eds
# CLIP: 318114, eds
# CLIP: 318138, eds
# CLIP: 318238, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 50
# CLIP: 318455, eds
# CLIP: 318908, eds
# CLIP: 319100, eds
# CLIP: 319184, eds
# CLIP: 319369, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319534, eds
# CLIP: 319607, eds
# CLIP: 319617, eds
# CLIP: 319696, eds
# CLIP: 319721, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319935, eds
# CLIP: 320232, eds
# CLIP: 320425, eds
# CLIP: 320490, eds
# CLIP: 320554, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320632, eds
# CLIP: 320642, eds
# CLIP: 320664, eds
# CLIP: 320696, eds
# CLIP: 320706, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320743, eds
# CLIP: 321118, eds
# CLIP: 321214, eds
# CLIP: 321333, eds
# CLIP: 321557, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 321790, eds
# CLIP: 321887, eds
# CLIP: 322163, eds
# CLIP: 322211, eds
# CLIP: 322352, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322429, eds
# CLIP: 322574, eds
# CLIP: 322610, eds
# CLIP: 322724, eds
# CLIP: 322829, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322844, eds
# CLIP: 322864, eds
# CLIP: 322895, eds
# CLIP: 322944, eds
# CLIP: 322959, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322968, eds
# CLIP: 323151, eds
# CLIP: 323202, eds
# CLIP: 323263, eds
# CLIP: 323355, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 323496, eds
# CLIP: 323571, eds
# CLIP: 323709, eds
# CLIP: 323751, eds
# CLIP: 323799, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 60
# CLIP: 323828, eds
# CLIP: 323895, eds
# CLIP: 324158, eds
# CLIP: 324258, eds
# CLIP: 324614, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 324715, eds
# CLIP: 324818, eds
# CLIP: 324927, eds
# CLIP: 325031, eds
# CLIP: 325114, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325306, eds
# CLIP: 325347, eds
# CLIP: 325483, eds
# CLIP: 325527, eds
# CLIP: 325838, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325991, eds
# CLIP: 326082, eds
# CLIP: 326128, eds
# CLIP: 326174, eds
# CLIP: 326248, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 326462, eds
# CLIP: 326541, eds
# CLIP: 326542, eds
# CLIP: 326627, eds
# CLIP: 326970, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327306, eds
# CLIP: 327592, eds
# CLIP: 327601, eds
# CLIP: 327605, eds
# CLIP: 327617, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327701, eds
# CLIP: 327769, eds
# CLIP: 327780, eds
# CLIP: 327890, eds
# CLIP: 328030, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328117, eds
# CLIP: 328238, eds
# CLIP: 328286, eds
# CLIP: 328337, eds
# CLIP: 328430, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328601, eds
# CLIP: 328683, eds
# CLIP: 328959, eds
# CLIP: 329041, eds
# CLIP: 329080, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 329219, eds
# CLIP: 329319, eds
# CLIP: 329323, eds
# CLIP: 329447, eds
# CLIP: 329455, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 70
# CLIP: 329456, eds
# CLIP: 329542, eds
# CLIP: 329614, eds
# CLIP: 329827, eds
# CLIP: 330369, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 330396, eds
# CLIP: 330554, eds
# CLIP: 330790, eds
# CLIP: 330818, eds
# CLIP: 331075, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331280, eds
# CLIP: 331317, eds
# CLIP: 331352, eds
# CLIP: 331569, eds
# CLIP: 331604, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331799, eds
# CLIP: 331817, eds
# CLIP: 332318, eds
# CLIP: 332351, eds
# CLIP: 332455, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 332570, eds
# CLIP: 332845, eds
# CLIP: 332901, eds
# CLIP: 333069, eds
# CLIP: 333237, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 333402, eds
# CLIP: 333697, eds
# CLIP: 333745, eds
# CLIP: 333772, eds
# CLIP: 333956, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334006, eds
# CLIP: 334309, eds
# CLIP: 334371, eds
# CLIP: 334399, eds
# CLIP: 334417, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334483, eds
# CLIP: 334521, eds
# CLIP: 334530, eds
# CLIP: 334555, eds
# CLIP: 334719, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334767, eds
# CLIP: 334977, eds
# CLIP: 335081, eds
# CLIP: 335177, eds
# CLIP: 335328, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 335427, eds
# CLIP: 335450, eds
# CLIP: 335529, eds
# CLIP: 335658, eds
# CLIP: 335800, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 80
# CLIP: 335954, eds
# CLIP: 336053, eds
# CLIP: 336209, eds
# CLIP: 336232, eds
# CLIP: 336265, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 336309, eds
# CLIP: 336356, eds
# CLIP: 336587, eds
# CLIP: 336628, eds
# CLIP: 336658, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 337055, eds
# CLIP: 337498, eds
# CLIP: 337987, eds
# CLIP: 338191, eds
# CLIP: 338219, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338304, eds
# CLIP: 338325, eds
# CLIP: 338428, eds
# CLIP: 338532, eds
# CLIP: 338560, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338624, eds
# CLIP: 338625, eds
# CLIP: 338718, eds
# CLIP: 338901, eds
# CLIP: 338905, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338986, eds
# CLIP: 339442, eds
# CLIP: 339823, eds
# CLIP: 339870, eds
# CLIP: 340015, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340175, eds
# CLIP: 340272, eds
# CLIP: 340451, eds
# CLIP: 340697, eds
# CLIP: 340894, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340930, eds
# CLIP: 341058, eds
# CLIP: 341094, eds
# CLIP: 341196, eds
# CLIP: 341469, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 341681, eds
# CLIP: 341719, eds
# CLIP: 341828, eds
# CLIP: 341921, eds
# CLIP: 341973, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 342006, eds
# CLIP: 342128, eds
# CLIP: 342186, eds
# CLIP: 342295, eds
# CLIP: 342367, eds
# 	COMPUTED 5 CLIP SCORES
# scheduler name: eds, batch_idx: 90
# CLIP: 342397, eds
# CLIP: 342971, eds
# CLIP: 343076, eds
# CLIP: 343149, eds
# CLIP: 343218, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343315, eds
# CLIP: 343453, eds
# CLIP: 343466, eds
# CLIP: 343496, eds
# CLIP: 343524, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343561, eds
# CLIP: 343706, eds
# CLIP: 343803, eds
# CLIP: 343934, eds
# CLIP: 343937, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343976, eds
# CLIP: 344029, eds
# CLIP: 344059, eds
# CLIP: 344100, eds
# CLIP: 344268, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344611, eds
# CLIP: 344614, eds
# CLIP: 344621, eds
# CLIP: 344795, eds
# CLIP: 344816, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344888, eds
# CLIP: 344909, eds
# CLIP: 345027, eds
# CLIP: 345252, eds
# CLIP: 345261, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345356, eds
# CLIP: 345361, eds
# CLIP: 345385, eds
# CLIP: 345397, eds
# CLIP: 345466, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345469, eds
# CLIP: 345941, eds
# CLIP: 346232, eds
# CLIP: 346638, eds
# CLIP: 346703, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 346707, eds
# CLIP: 346905, eds
# CLIP: 346968, eds
# CLIP: 347163, eds
# CLIP: 347174, eds
# 	COMPUTED 5 CLIP SCORES
# CLIP: 347254, eds
# CLIP: 347265, eds
# CLIP: 347370, eds
# CLIP: 347456, eds
# 	COMPUTED 4 CLIP SCORES
# scheduler name: eds, batch_idx: 100
# SCHEDULER: heun
# CLIP: 289594, heun
# CLIP: 289659, heun
# CLIP: 289702, heun
# CLIP: 289741, heun
# CLIP: 289938, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 289960, heun
# CLIP: 289992, heun
# CLIP: 290081, heun
# CLIP: 290163, heun
# CLIP: 290179, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290248, heun
# CLIP: 290293, heun
# CLIP: 290592, heun
# CLIP: 290619, heun
# CLIP: 290768, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290771, heun
# CLIP: 290833, heun
# CLIP: 290843, heun
# CLIP: 291490, heun
# CLIP: 291551, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 291619, heun
# CLIP: 291634, heun
# CLIP: 291664, heun
# CLIP: 291791, heun
# CLIP: 291861, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292005, heun
# CLIP: 292024, heun
# CLIP: 292060, heun
# CLIP: 292082, heun
# CLIP: 292155, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292225, heun
# CLIP: 292236, heun
# CLIP: 292330, heun
# CLIP: 292415, heun
# CLIP: 292446, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292456, heun
# CLIP: 292488, heun
# CLIP: 292908, heun
# CLIP: 292997, heun
# CLIP: 293044, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293071, heun
# CLIP: 293200, heun
# CLIP: 293245, heun
# CLIP: 293300, heun
# CLIP: 293324, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293474, heun
# CLIP: 293625, heun
# CLIP: 293794, heun
# CLIP: 293804, heun
# 	COMPUTED 4 CLIP SCORES
# scheduler name: heun, batch_idx: 10
# CLIP: 293858, heun
# CLIP: 294162, heun
# CLIP: 294163, heun
# CLIP: 294695, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 294783, heun
# CLIP: 294831, heun
# CLIP: 294855, heun
# CLIP: 295138, heun
# CLIP: 295231, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295316, heun
# CLIP: 295420, heun
# CLIP: 295478, heun
# CLIP: 295797, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 295809, heun
# CLIP: 296222, heun
# CLIP: 296224, heun
# CLIP: 296231, heun
# CLIP: 296284, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 296317, heun
# CLIP: 296634, heun
# CLIP: 296649, heun
# CLIP: 296657, heun
# CLIP: 296969, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297022, heun
# CLIP: 297084, heun
# CLIP: 297085, heun
# CLIP: 297147, heun
# CLIP: 297343, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297353, heun
# CLIP: 297396, heun
# CLIP: 297427, heun
# CLIP: 297562, heun
# CLIP: 297578, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297595, heun
# CLIP: 297681, heun
# CLIP: 297698, heun
# CLIP: 297830, heun
# CLIP: 298251, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 298697, heun
# CLIP: 298738, heun
# CLIP: 298904, heun
# CLIP: 298994, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 299355, heun
# CLIP: 299553, heun
# CLIP: 299609, heun
# CLIP: 299720, heun
# CLIP: 299887, heun
# 	COMPUTED 5 CLIP SCORES
# scheduler name: heun, batch_idx: 20
# CLIP: 300039, heun
# CLIP: 300233, heun
# CLIP: 300276, heun
# CLIP: 300341, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 300659, heun
# CLIP: 300842, heun
# CLIP: 300913, heun
# CLIP: 301061, heun
# CLIP: 301135, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301376, heun
# CLIP: 301421, heun
# CLIP: 301563, heun
# CLIP: 301718, heun
# CLIP: 301867, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301981, heun
# CLIP: 302030, heun
# CLIP: 302107, heun
# CLIP: 302165, heun
# CLIP: 302452, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 302536, heun
# CLIP: 302760, heun
# CLIP: 302882, heun
# CLIP: 302990, heun
# CLIP: 303305, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303499, heun
# CLIP: 303566, heun
# CLIP: 303653, heun
# CLIP: 303713, heun
# CLIP: 303818, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303863, heun
# CLIP: 303893, heun
# CLIP: 303908, heun
# CLIP: 304180, heun
# CLIP: 304291, heun
#   0%|          | 0/20 [00:00<?, ?it/s]
# 	GENERATED 1 IMAGES
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304365, heun
# CLIP: 304404, heun
# CLIP: 304545, heun
# CLIP: 304560, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 304812, heun
# CLIP: 304817, heun
# CLIP: 304984, heun
# CLIP: 305309, heun
# CLIP: 305317, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 305343, heun
# CLIP: 305609, heun
# CLIP: 305695, heun
# CLIP: 306136, heun
# CLIP: 306139, heun
# 	COMPUTED 5 CLIP SCORES
# scheduler name: heun, batch_idx: 30
# CLIP: 306437, heun
# CLIP: 306582, heun
# CLIP: 306700, heun
# CLIP: 306733, heun
# CLIP: 306893, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 307145, heun
# CLIP: 307172, heun
# CLIP: 307658, heun
# 	COMPUTED 3 CLIP SCORES
# CLIP: 308165, heun
# CLIP: 308193, heun
# CLIP: 308328, heun
# CLIP: 308391, heun
# CLIP: 308394, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308466, heun
# CLIP: 308476, heun
# CLIP: 308531, heun
# CLIP: 308545, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 308587, heun
# CLIP: 308631, heun
# CLIP: 308753, heun
# CLIP: 308799, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309391, heun
# CLIP: 309452, heun
# CLIP: 309467, heun
# CLIP: 309484, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309495, heun
# CLIP: 309655, heun
# CLIP: 309678, heun
# CLIP: 309938, heun
# CLIP: 309964, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 310072, heun
# CLIP: 310200, heun
# CLIP: 310622, heun
# CLIP: 310862, heun
# CLIP: 310980, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311002, heun
# CLIP: 311081, heun
# CLIP: 311180, heun
# 	COMPUTED 3 CLIP SCORES
# CLIP: 311303, heun
# CLIP: 311392, heun
# CLIP: 311394, heun
# CLIP: 311789, heun
# 	COMPUTED 4 CLIP SCORES
# scheduler name: heun, batch_idx: 40
# CLIP: 311883, heun
# CLIP: 311928, heun
# CLIP: 311950, heun
# CLIP: 312192, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 312213, heun
# CLIP: 312237, heun
# CLIP: 312263, heun
# CLIP: 312278, heun
# CLIP: 312340, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312406, heun
# CLIP: 312421, heun
# CLIP: 312489, heun
# CLIP: 312549, heun
# CLIP: 312552, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312720, heun
# CLIP: 313130, heun
# CLIP: 313182, heun
# 	COMPUTED 3 CLIP SCORES
# CLIP: 313562, heun
# CLIP: 313588, heun
# CLIP: 314034, heun
# 	COMPUTED 3 CLIP SCORES
# CLIP: 314177, heun
# CLIP: 314182, heun
# CLIP: 314251, heun
# CLIP: 314264, heun
# CLIP: 314294, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314541, heun
# CLIP: 314914, heun
# CLIP: 315001, heun
# CLIP: 315187, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 315219, heun
# CLIP: 315257, heun
# CLIP: 315450, heun
# CLIP: 316015, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 316054, heun
# CLIP: 316666, heun
# CLIP: 317024, heun
# CLIP: 317433, heun
#   0%|          | 0/20 [00:00<?, ?it/s]
# 	GENERATED 1 IMAGES
# 	COMPUTED 4 CLIP SCORES
# CLIP: 318080, heun
# CLIP: 318114, heun
# CLIP: 318138, heun
# CLIP: 318238, heun
# 	COMPUTED 4 CLIP SCORES
# scheduler name: heun, batch_idx: 50
# CLIP: 318455, heun
# CLIP: 318908, heun
# CLIP: 319184, heun
# CLIP: 319369, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 319534, heun
# CLIP: 319607, heun
# CLIP: 319617, heun
# CLIP: 319696, heun
# CLIP: 319721, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319935, heun
# CLIP: 320232, heun
# CLIP: 320425, heun
# CLIP: 320490, heun
# CLIP: 320554, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320632, heun
# CLIP: 320664, heun
# CLIP: 320696, heun
# 	COMPUTED 3 CLIP SCORES
# CLIP: 320743, heun
# CLIP: 321118, heun
# CLIP: 321214, heun
# CLIP: 321333, heun
# CLIP: 321557, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 321790, heun
# CLIP: 321887, heun
# CLIP: 322163, heun
# CLIP: 322211, heun
# CLIP: 322352, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322429, heun
# CLIP: 322574, heun
# CLIP: 322610, heun
# CLIP: 322724, heun
# CLIP: 322829, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322844, heun
# CLIP: 322864, heun
# CLIP: 322895, heun
# CLIP: 322944, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 322968, heun
# CLIP: 323151, heun
# CLIP: 323202, heun
# CLIP: 323263, heun
# CLIP: 323355, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 323496, heun
# CLIP: 323571, heun
# CLIP: 323709, heun
# CLIP: 323751, heun
# 	COMPUTED 4 CLIP SCORES
# scheduler name: heun, batch_idx: 60
# CLIP: 323828, heun
# CLIP: 323895, heun
# CLIP: 324158, heun
# CLIP: 324258, heun
# CLIP: 324614, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 324715, heun
# CLIP: 324927, heun
# CLIP: 325031, heun
# CLIP: 325114, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 325306, heun
# CLIP: 325347, heun
# CLIP: 325483, heun
# CLIP: 325527, heun
# CLIP: 325838, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325991, heun
# CLIP: 326082, heun
# CLIP: 326128, heun
# CLIP: 326174, heun
# CLIP: 326248, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 326462, heun
# CLIP: 326541, heun
# CLIP: 326542, heun
# CLIP: 326627, heun
# CLIP: 326970, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327592, heun
# CLIP: 327601, heun
# CLIP: 327605, heun
# CLIP: 327617, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 327701, heun
# CLIP: 327769, heun
# CLIP: 327780, heun
# CLIP: 327890, heun
# CLIP: 328030, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328117, heun
# CLIP: 328238, heun
# CLIP: 328286, heun
# CLIP: 328337, heun
# CLIP: 328430, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328683, heun
# CLIP: 328959, heun
# CLIP: 329041, heun
# CLIP: 329080, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 329219, heun
# CLIP: 329319, heun
# CLIP: 329323, heun
# CLIP: 329447, heun
# CLIP: 329455, heun
# 	COMPUTED 5 CLIP SCORES
# scheduler name: heun, batch_idx: 70
# CLIP: 329456, heun
# CLIP: 329542, heun
# CLIP: 329614, heun
# CLIP: 329827, heun
# CLIP: 330369, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 330396, heun
# CLIP: 330554, heun
# CLIP: 330790, heun
# CLIP: 330818, heun
# CLIP: 331075, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331280, heun
# CLIP: 331352, heun
# CLIP: 331569, heun
# CLIP: 331604, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 331799, heun
# CLIP: 331817, heun
# CLIP: 332318, heun
# CLIP: 332351, heun
# CLIP: 332455, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 332570, heun
# CLIP: 332845, heun
# CLIP: 332901, heun
# CLIP: 333069, heun
# CLIP: 333237, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 333402, heun
# CLIP: 333697, heun
# CLIP: 333745, heun
# CLIP: 333772, heun
# CLIP: 333956, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334006, heun
# CLIP: 334309, heun
# CLIP: 334371, heun
# CLIP: 334399, heun
# CLIP: 334417, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334483, heun
# CLIP: 334521, heun
# CLIP: 334530, heun
# CLIP: 334555, heun
# CLIP: 334719, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334767, heun
# CLIP: 334977, heun
# CLIP: 335081, heun
# CLIP: 335328, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 335427, heun
# CLIP: 335450, heun
# CLIP: 335529, heun
# CLIP: 335658, heun
# CLIP: 335800, heun
# 	COMPUTED 5 CLIP SCORES
# scheduler name: heun, batch_idx: 80
# CLIP: 335954, heun
# CLIP: 336053, heun
# CLIP: 336209, heun
# CLIP: 336232, heun
# CLIP: 336265, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 336309, heun
# CLIP: 336356, heun
# CLIP: 336628, heun
# CLIP: 336658, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 337055, heun
# CLIP: 337498, heun
# CLIP: 337987, heun
# CLIP: 338191, heun
# CLIP: 338219, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338304, heun
# CLIP: 338325, heun
# CLIP: 338428, heun
# CLIP: 338532, heun
# CLIP: 338560, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338624, heun
# CLIP: 338718, heun
# 	COMPUTED 2 CLIP SCORES
# CLIP: 338986, heun
# CLIP: 339442, heun
# CLIP: 339823, heun
# CLIP: 339870, heun
# CLIP: 340015, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340175, heun
# CLIP: 340272, heun
# CLIP: 340451, heun
# CLIP: 340697, heun
# CLIP: 340894, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340930, heun
# CLIP: 341094, heun
# CLIP: 341196, heun
# CLIP: 341469, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 341681, heun
# CLIP: 341719, heun
# CLIP: 341828, heun
# CLIP: 341921, heun
# CLIP: 341973, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 342006, heun
# CLIP: 342128, heun
# CLIP: 342186, heun
# CLIP: 342367, heun
# 	COMPUTED 4 CLIP SCORES
# scheduler name: heun, batch_idx: 90
# CLIP: 342397, heun
# CLIP: 342971, heun
# CLIP: 343076, heun
# CLIP: 343149, heun
# CLIP: 343218, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343315, heun
# CLIP: 343453, heun
# CLIP: 343466, heun
# CLIP: 343496, heun
# CLIP: 343524, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343561, heun
# CLIP: 343706, heun
# CLIP: 343803, heun
# CLIP: 343934, heun
# CLIP: 343937, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343976, heun
# CLIP: 344029, heun
# CLIP: 344059, heun
# CLIP: 344100, heun
# CLIP: 344268, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344611, heun
# CLIP: 344614, heun
# CLIP: 344621, heun
# CLIP: 344795, heun
# CLIP: 344816, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344888, heun
# CLIP: 344909, heun
# CLIP: 345027, heun
# CLIP: 345252, heun
# CLIP: 345261, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345356, heun
# CLIP: 345361, heun
# CLIP: 345385, heun
# CLIP: 345397, heun
# CLIP: 345466, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345469, heun
# CLIP: 345941, heun
# CLIP: 346232, heun
# CLIP: 346638, heun
# CLIP: 346703, heun
# 	COMPUTED 5 CLIP SCORES
# CLIP: 346905, heun
# CLIP: 346968, heun
# CLIP: 347163, heun
# CLIP: 347174, heun
# 	COMPUTED 4 CLIP SCORES
# CLIP: 347254, heun
# CLIP: 347265, heun
# CLIP: 347456, heun
# 	COMPUTED 3 CLIP SCORES
# scheduler name: heun, batch_idx: 100
# SCHEDULER: ddpm
# CLIP: 289594, ddpm
# CLIP: 289659, ddpm
# CLIP: 289702, ddpm
# CLIP: 289741, ddpm
# CLIP: 289938, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 289960, ddpm
# CLIP: 289992, ddpm
# CLIP: 290081, ddpm
# CLIP: 290163, ddpm
# CLIP: 290179, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290248, ddpm
# CLIP: 290293, ddpm
# CLIP: 290592, ddpm
# CLIP: 290619, ddpm
# CLIP: 290768, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290771, ddpm
# CLIP: 290833, ddpm
# CLIP: 290843, ddpm
# CLIP: 291490, ddpm
# CLIP: 291551, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 291619, ddpm
# CLIP: 291634, ddpm
# CLIP: 291664, ddpm
# CLIP: 291791, ddpm
# CLIP: 291861, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292005, ddpm
# CLIP: 292024, ddpm
# CLIP: 292060, ddpm
# CLIP: 292082, ddpm
# CLIP: 292155, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292225, ddpm
# CLIP: 292236, ddpm
# CLIP: 292330, ddpm
# CLIP: 292415, ddpm
# CLIP: 292446, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292456, ddpm
# CLIP: 292488, ddpm
# CLIP: 292908, ddpm
# CLIP: 292997, ddpm
# CLIP: 293044, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293071, ddpm
# CLIP: 293200, ddpm
# CLIP: 293245, ddpm
# CLIP: 293300, ddpm
# CLIP: 293324, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293474, ddpm
# CLIP: 293625, ddpm
# CLIP: 293794, ddpm
# CLIP: 293804, ddpm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddpm, batch_idx: 10
# CLIP: 293858, ddpm
# CLIP: 294162, ddpm
# CLIP: 294163, ddpm
# CLIP: 294695, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 294783, ddpm
# CLIP: 294831, ddpm
# CLIP: 294855, ddpm
# CLIP: 295138, ddpm
# CLIP: 295231, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295316, ddpm
# CLIP: 295420, ddpm
# CLIP: 295478, ddpm
# CLIP: 295797, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 295809, ddpm
# CLIP: 296222, ddpm
# CLIP: 296224, ddpm
# CLIP: 296231, ddpm
# CLIP: 296284, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 296317, ddpm
# CLIP: 296634, ddpm
# CLIP: 296649, ddpm
# CLIP: 296657, ddpm
# CLIP: 296969, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297022, ddpm
# CLIP: 297084, ddpm
# CLIP: 297085, ddpm
# CLIP: 297147, ddpm
# CLIP: 297343, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297353, ddpm
# CLIP: 297396, ddpm
# CLIP: 297427, ddpm
# CLIP: 297562, ddpm
# CLIP: 297578, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297595, ddpm
# CLIP: 297681, ddpm
# CLIP: 297698, ddpm
# CLIP: 297830, ddpm
# CLIP: 298251, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 298697, ddpm
# CLIP: 298738, ddpm
# CLIP: 298904, ddpm
# CLIP: 298994, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 299355, ddpm
# CLIP: 299553, ddpm
# CLIP: 299609, ddpm
# CLIP: 299720, ddpm
# CLIP: 299887, ddpm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddpm, batch_idx: 20
# CLIP: 300039, ddpm
# CLIP: 300233, ddpm
# CLIP: 300276, ddpm
# CLIP: 300341, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 300659, ddpm
# CLIP: 300842, ddpm
# CLIP: 300913, ddpm
# CLIP: 301061, ddpm
# CLIP: 301135, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301376, ddpm
# CLIP: 301421, ddpm
# CLIP: 301563, ddpm
# CLIP: 301718, ddpm
# CLIP: 301867, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301981, ddpm
# CLIP: 302030, ddpm
# CLIP: 302107, ddpm
# CLIP: 302165, ddpm
# CLIP: 302452, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 302536, ddpm
# CLIP: 302760, ddpm
# CLIP: 302882, ddpm
# CLIP: 302990, ddpm
# CLIP: 303305, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303499, ddpm
# CLIP: 303566, ddpm
# CLIP: 303653, ddpm
# CLIP: 303713, ddpm
# CLIP: 303818, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303863, ddpm
# CLIP: 303893, ddpm
# CLIP: 303908, ddpm
# CLIP: 304180, ddpm
# CLIP: 304291, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304365, ddpm
# CLIP: 304404, ddpm
# CLIP: 304545, ddpm
# CLIP: 304560, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 304812, ddpm
# CLIP: 304817, ddpm
# CLIP: 304984, ddpm
# CLIP: 305309, ddpm
# CLIP: 305317, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 305343, ddpm
# CLIP: 305609, ddpm
# CLIP: 305695, ddpm
# CLIP: 306136, ddpm
# CLIP: 306139, ddpm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddpm, batch_idx: 30
# CLIP: 306437, ddpm
# CLIP: 306582, ddpm
# CLIP: 306700, ddpm
# CLIP: 306733, ddpm
# CLIP: 306893, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 307145, ddpm
# CLIP: 307172, ddpm
# CLIP: 307658, ddpm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 308165, ddpm
# CLIP: 308193, ddpm
# CLIP: 308328, ddpm
# CLIP: 308391, ddpm
# CLIP: 308394, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308466, ddpm
# CLIP: 308476, ddpm
# CLIP: 308531, ddpm
# CLIP: 308545, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 308587, ddpm
# CLIP: 308631, ddpm
# CLIP: 308753, ddpm
# CLIP: 308799, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309391, ddpm
# CLIP: 309452, ddpm
# CLIP: 309467, ddpm
# CLIP: 309484, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309495, ddpm
# CLIP: 309655, ddpm
# CLIP: 309678, ddpm
# CLIP: 309938, ddpm
# CLIP: 309964, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 310072, ddpm
# CLIP: 310200, ddpm
# CLIP: 310622, ddpm
# CLIP: 310862, ddpm
# CLIP: 310980, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311002, ddpm
# CLIP: 311081, ddpm
# CLIP: 311180, ddpm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 311303, ddpm
# CLIP: 311392, ddpm
# CLIP: 311394, ddpm
# CLIP: 311789, ddpm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddpm, batch_idx: 40
# CLIP: 311883, ddpm
# CLIP: 311928, ddpm
# CLIP: 311950, ddpm
# CLIP: 312192, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 312213, ddpm
# CLIP: 312237, ddpm
# CLIP: 312263, ddpm
# CLIP: 312278, ddpm
# CLIP: 312340, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312406, ddpm
# CLIP: 312421, ddpm
# CLIP: 312489, ddpm
# CLIP: 312549, ddpm
# CLIP: 312552, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312720, ddpm
# CLIP: 313130, ddpm
# CLIP: 313182, ddpm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 313562, ddpm
# CLIP: 313588, ddpm
# CLIP: 314034, ddpm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 314177, ddpm
# CLIP: 314182, ddpm
# CLIP: 314251, ddpm
# CLIP: 314264, ddpm
# CLIP: 314294, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314541, ddpm
# CLIP: 314914, ddpm
# CLIP: 315001, ddpm
# CLIP: 315187, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 315219, ddpm
# CLIP: 315257, ddpm
# CLIP: 315450, ddpm
# CLIP: 316015, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 316054, ddpm
# CLIP: 316666, ddpm
# CLIP: 317024, ddpm
# CLIP: 317433, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 318080, ddpm
# CLIP: 318114, ddpm
# CLIP: 318138, ddpm
# CLIP: 318238, ddpm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddpm, batch_idx: 50
# CLIP: 318455, ddpm
# CLIP: 318908, ddpm
# CLIP: 319184, ddpm
# CLIP: 319369, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 319534, ddpm
# CLIP: 319607, ddpm
# CLIP: 319617, ddpm
# CLIP: 319696, ddpm
# CLIP: 319721, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319935, ddpm
# CLIP: 320232, ddpm
# CLIP: 320425, ddpm
# CLIP: 320490, ddpm
# CLIP: 320554, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320632, ddpm
# CLIP: 320664, ddpm
# CLIP: 320696, ddpm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 320743, ddpm
# CLIP: 321118, ddpm
# CLIP: 321214, ddpm
# CLIP: 321333, ddpm
# CLIP: 321557, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 321790, ddpm
# CLIP: 321887, ddpm
# CLIP: 322163, ddpm
# CLIP: 322211, ddpm
# CLIP: 322352, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322429, ddpm
# CLIP: 322574, ddpm
# CLIP: 322610, ddpm
# CLIP: 322724, ddpm
# CLIP: 322829, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322844, ddpm
# CLIP: 322864, ddpm
# CLIP: 322895, ddpm
# CLIP: 322944, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 322968, ddpm
# CLIP: 323151, ddpm
# CLIP: 323202, ddpm
# CLIP: 323263, ddpm
# CLIP: 323355, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 323496, ddpm
# CLIP: 323571, ddpm
# CLIP: 323709, ddpm
# CLIP: 323751, ddpm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddpm, batch_idx: 60
# CLIP: 323828, ddpm
# CLIP: 323895, ddpm
# CLIP: 324158, ddpm
# CLIP: 324258, ddpm
# CLIP: 324614, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 324715, ddpm
# CLIP: 324927, ddpm
# CLIP: 325031, ddpm
# CLIP: 325114, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 325306, ddpm
# CLIP: 325347, ddpm
# CLIP: 325483, ddpm
# CLIP: 325527, ddpm
# CLIP: 325838, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325991, ddpm
# CLIP: 326082, ddpm
# CLIP: 326128, ddpm
# CLIP: 326174, ddpm
# CLIP: 326248, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 326462, ddpm
# CLIP: 326541, ddpm
# CLIP: 326542, ddpm
# CLIP: 326627, ddpm
# CLIP: 326970, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327592, ddpm
# CLIP: 327601, ddpm
# CLIP: 327605, ddpm
# CLIP: 327617, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 327701, ddpm
# CLIP: 327769, ddpm
# CLIP: 327780, ddpm
# CLIP: 327890, ddpm
# CLIP: 328030, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328117, ddpm
# CLIP: 328238, ddpm
# CLIP: 328286, ddpm
# CLIP: 328337, ddpm
# CLIP: 328430, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328683, ddpm
# CLIP: 328959, ddpm
# CLIP: 329041, ddpm
# CLIP: 329080, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 329219, ddpm
# CLIP: 329319, ddpm
# CLIP: 329323, ddpm
# CLIP: 329447, ddpm
# CLIP: 329455, ddpm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddpm, batch_idx: 70
# CLIP: 329456, ddpm
# CLIP: 329542, ddpm
# CLIP: 329614, ddpm
# CLIP: 329827, ddpm
# CLIP: 330369, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 330396, ddpm
# CLIP: 330554, ddpm
# CLIP: 330790, ddpm
# CLIP: 330818, ddpm
# CLIP: 331075, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331280, ddpm
# CLIP: 331352, ddpm
# CLIP: 331569, ddpm
# CLIP: 331604, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 331799, ddpm
# CLIP: 331817, ddpm
# CLIP: 332318, ddpm
# CLIP: 332351, ddpm
# CLIP: 332455, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 332570, ddpm
# CLIP: 332845, ddpm
# CLIP: 332901, ddpm
# CLIP: 333069, ddpm
# CLIP: 333237, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 333402, ddpm
# CLIP: 333697, ddpm
# CLIP: 333745, ddpm
# CLIP: 333772, ddpm
# CLIP: 333956, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334006, ddpm
# CLIP: 334309, ddpm
# CLIP: 334371, ddpm
# CLIP: 334399, ddpm
# CLIP: 334417, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334483, ddpm
# CLIP: 334521, ddpm
# CLIP: 334530, ddpm
# CLIP: 334555, ddpm
# CLIP: 334719, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334767, ddpm
# CLIP: 334977, ddpm
# CLIP: 335081, ddpm
# CLIP: 335328, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 335427, ddpm
# CLIP: 335450, ddpm
# CLIP: 335529, ddpm
# CLIP: 335658, ddpm
# CLIP: 335800, ddpm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddpm, batch_idx: 80
# CLIP: 335954, ddpm
# CLIP: 336053, ddpm
# CLIP: 336209, ddpm
# CLIP: 336232, ddpm
# CLIP: 336265, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 336309, ddpm
# CLIP: 336356, ddpm
# CLIP: 336628, ddpm
# CLIP: 336658, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 337055, ddpm
# CLIP: 337498, ddpm
# CLIP: 337987, ddpm
# CLIP: 338191, ddpm
# CLIP: 338219, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338304, ddpm
# CLIP: 338325, ddpm
# CLIP: 338428, ddpm
# CLIP: 338532, ddpm
# CLIP: 338560, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338624, ddpm
# CLIP: 338718, ddpm
# 	COMPUTED 2 CLIP SCORES
# CLIP: 338986, ddpm
# CLIP: 339442, ddpm
# CLIP: 339823, ddpm
# CLIP: 339870, ddpm
# CLIP: 340015, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340175, ddpm
# CLIP: 340272, ddpm
# CLIP: 340451, ddpm
# CLIP: 340697, ddpm
# CLIP: 340894, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340930, ddpm
# CLIP: 341094, ddpm
# CLIP: 341196, ddpm
# CLIP: 341469, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 341681, ddpm
# CLIP: 341719, ddpm
# CLIP: 341828, ddpm
# CLIP: 341921, ddpm
# CLIP: 341973, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 342006, ddpm
# CLIP: 342128, ddpm
# CLIP: 342186, ddpm
# CLIP: 342367, ddpm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddpm, batch_idx: 90
# CLIP: 342397, ddpm
# CLIP: 342971, ddpm
# CLIP: 343076, ddpm
# CLIP: 343149, ddpm
# CLIP: 343218, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343315, ddpm
# CLIP: 343453, ddpm
# CLIP: 343466, ddpm
# CLIP: 343496, ddpm
# CLIP: 343524, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343561, ddpm
# CLIP: 343706, ddpm
# CLIP: 343803, ddpm
# CLIP: 343934, ddpm
# CLIP: 343937, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343976, ddpm
# CLIP: 344029, ddpm
# CLIP: 344059, ddpm
# CLIP: 344100, ddpm
# CLIP: 344268, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344611, ddpm
# CLIP: 344614, ddpm
# CLIP: 344621, ddpm
# CLIP: 344795, ddpm
# CLIP: 344816, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344888, ddpm
# CLIP: 344909, ddpm
# CLIP: 345027, ddpm
# CLIP: 345252, ddpm
# CLIP: 345261, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345356, ddpm
# CLIP: 345361, ddpm
# CLIP: 345385, ddpm
# CLIP: 345397, ddpm
# CLIP: 345466, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345469, ddpm
# CLIP: 345941, ddpm
# CLIP: 346232, ddpm
# CLIP: 346638, ddpm
# CLIP: 346703, ddpm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 346905, ddpm
# CLIP: 346968, ddpm
# CLIP: 347163, ddpm
# CLIP: 347174, ddpm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 347254, ddpm
# CLIP: 347456, ddpm
# 	COMPUTED 2 CLIP SCORES
# scheduler name: ddpm, batch_idx: 100
# SCHEDULER: pndm
# CLIP: 289594, pndm
# CLIP: 289659, pndm
# CLIP: 289702, pndm
# CLIP: 289741, pndm
# CLIP: 289938, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 289960, pndm
# CLIP: 289992, pndm
# CLIP: 290081, pndm
# CLIP: 290163, pndm
# CLIP: 290179, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290248, pndm
# CLIP: 290293, pndm
# CLIP: 290592, pndm
# CLIP: 290619, pndm
# CLIP: 290768, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290771, pndm
# CLIP: 290833, pndm
# CLIP: 290843, pndm
# CLIP: 291490, pndm
# CLIP: 291551, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 291619, pndm
# CLIP: 291634, pndm
# CLIP: 291664, pndm
# CLIP: 291791, pndm
# CLIP: 291861, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292005, pndm
# CLIP: 292024, pndm
# CLIP: 292060, pndm
# CLIP: 292082, pndm
# CLIP: 292155, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292225, pndm
# CLIP: 292236, pndm
# CLIP: 292330, pndm
# CLIP: 292415, pndm
# CLIP: 292446, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292456, pndm
# CLIP: 292488, pndm
# CLIP: 292908, pndm
# CLIP: 292997, pndm
# CLIP: 293044, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293071, pndm
# CLIP: 293200, pndm
# CLIP: 293245, pndm
# CLIP: 293300, pndm
# CLIP: 293324, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293474, pndm
# CLIP: 293625, pndm
# CLIP: 293794, pndm
# CLIP: 293804, pndm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: pndm, batch_idx: 10
# CLIP: 293858, pndm
# CLIP: 294162, pndm
# CLIP: 294163, pndm
# CLIP: 294695, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 294783, pndm
# CLIP: 294831, pndm
# CLIP: 294855, pndm
# CLIP: 295138, pndm
# CLIP: 295231, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295316, pndm
# CLIP: 295420, pndm
# CLIP: 295478, pndm
# CLIP: 295797, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 295809, pndm
# CLIP: 296222, pndm
# CLIP: 296224, pndm
# CLIP: 296231, pndm
# CLIP: 296284, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 296317, pndm
# CLIP: 296634, pndm
# CLIP: 296649, pndm
# CLIP: 296657, pndm
# CLIP: 296969, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297022, pndm
# CLIP: 297084, pndm
# CLIP: 297085, pndm
# CLIP: 297147, pndm
# CLIP: 297343, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297353, pndm
# CLIP: 297396, pndm
# CLIP: 297427, pndm
# CLIP: 297562, pndm
# CLIP: 297578, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297595, pndm
# CLIP: 297681, pndm
# CLIP: 297698, pndm
# CLIP: 297830, pndm
# CLIP: 298251, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 298697, pndm
# CLIP: 298738, pndm
# CLIP: 298904, pndm
# CLIP: 298994, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 299355, pndm
# CLIP: 299553, pndm
# CLIP: 299609, pndm
# CLIP: 299720, pndm
# CLIP: 299887, pndm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: pndm, batch_idx: 20
# CLIP: 300039, pndm
# CLIP: 300233, pndm
# CLIP: 300276, pndm
# CLIP: 300341, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 300659, pndm
# CLIP: 300842, pndm
# CLIP: 300913, pndm
# CLIP: 301061, pndm
# CLIP: 301135, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301376, pndm
# CLIP: 301421, pndm
# CLIP: 301563, pndm
# CLIP: 301718, pndm
# CLIP: 301867, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301981, pndm
# CLIP: 302030, pndm
# CLIP: 302107, pndm
# CLIP: 302165, pndm
# CLIP: 302452, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 302536, pndm
# CLIP: 302760, pndm
# CLIP: 302882, pndm
# CLIP: 302990, pndm
# CLIP: 303305, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303499, pndm
# CLIP: 303566, pndm
# CLIP: 303653, pndm
# CLIP: 303713, pndm
# CLIP: 303818, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303863, pndm
# CLIP: 303893, pndm
# CLIP: 303908, pndm
# CLIP: 304180, pndm
# CLIP: 304291, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304365, pndm
# CLIP: 304404, pndm
# CLIP: 304545, pndm
# CLIP: 304560, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 304812, pndm
# CLIP: 304817, pndm
# CLIP: 304984, pndm
# CLIP: 305309, pndm
# CLIP: 305317, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 305343, pndm
# CLIP: 305609, pndm
# CLIP: 305695, pndm
# CLIP: 306136, pndm
# CLIP: 306139, pndm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: pndm, batch_idx: 30
# CLIP: 306437, pndm
# CLIP: 306582, pndm
# CLIP: 306700, pndm
# CLIP: 306733, pndm
# CLIP: 306893, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 307145, pndm
# CLIP: 307172, pndm
# CLIP: 307658, pndm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 308165, pndm
# CLIP: 308193, pndm
# CLIP: 308328, pndm
# CLIP: 308391, pndm
# CLIP: 308394, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308466, pndm
# CLIP: 308476, pndm
# CLIP: 308531, pndm
# CLIP: 308545, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 308587, pndm
# CLIP: 308631, pndm
# CLIP: 308753, pndm
# CLIP: 308799, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309391, pndm
# CLIP: 309452, pndm
# CLIP: 309467, pndm
# CLIP: 309484, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309495, pndm
# CLIP: 309655, pndm
# CLIP: 309678, pndm
# CLIP: 309938, pndm
# CLIP: 309964, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 310072, pndm
# CLIP: 310200, pndm
# CLIP: 310622, pndm
# CLIP: 310862, pndm
# CLIP: 310980, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311002, pndm
# CLIP: 311081, pndm
# CLIP: 311180, pndm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 311303, pndm
# CLIP: 311392, pndm
# CLIP: 311394, pndm
# CLIP: 311789, pndm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: pndm, batch_idx: 40
# CLIP: 311883, pndm
# CLIP: 311928, pndm
# CLIP: 311950, pndm
# CLIP: 312192, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 312213, pndm
# CLIP: 312237, pndm
# CLIP: 312263, pndm
# CLIP: 312278, pndm
# CLIP: 312340, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312406, pndm
# CLIP: 312421, pndm
# CLIP: 312489, pndm
# CLIP: 312549, pndm
# CLIP: 312552, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312720, pndm
# CLIP: 313130, pndm
# CLIP: 313182, pndm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 313562, pndm
# CLIP: 313588, pndm
# CLIP: 314034, pndm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 314177, pndm
# CLIP: 314182, pndm
# CLIP: 314251, pndm
# CLIP: 314264, pndm
# CLIP: 314294, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314541, pndm
# CLIP: 314914, pndm
# CLIP: 315001, pndm
# CLIP: 315187, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 315219, pndm
# CLIP: 315257, pndm
# CLIP: 315450, pndm
# CLIP: 316015, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 316054, pndm
# CLIP: 316666, pndm
# CLIP: 317024, pndm
# CLIP: 317433, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 318080, pndm
# CLIP: 318114, pndm
# CLIP: 318138, pndm
# CLIP: 318238, pndm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: pndm, batch_idx: 50
# CLIP: 318455, pndm
# CLIP: 318908, pndm
# CLIP: 319184, pndm
# CLIP: 319369, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 319534, pndm
# CLIP: 319607, pndm
# CLIP: 319617, pndm
# CLIP: 319696, pndm
# CLIP: 319721, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319935, pndm
# CLIP: 320232, pndm
# CLIP: 320425, pndm
# CLIP: 320490, pndm
# CLIP: 320554, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320632, pndm
# CLIP: 320664, pndm
# CLIP: 320696, pndm
# 	COMPUTED 3 CLIP SCORES
# CLIP: 320743, pndm
# CLIP: 321118, pndm
# CLIP: 321214, pndm
# CLIP: 321333, pndm
# CLIP: 321557, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 321790, pndm
# CLIP: 321887, pndm
# CLIP: 322163, pndm
# CLIP: 322211, pndm
# CLIP: 322352, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322429, pndm
# CLIP: 322574, pndm
# CLIP: 322610, pndm
# CLIP: 322724, pndm
# CLIP: 322829, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322844, pndm
# CLIP: 322864, pndm
# CLIP: 322895, pndm
# CLIP: 322944, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 322968, pndm
# CLIP: 323151, pndm
# CLIP: 323202, pndm
# CLIP: 323263, pndm
# CLIP: 323355, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 323496, pndm
# CLIP: 323571, pndm
# CLIP: 323709, pndm
# CLIP: 323751, pndm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: pndm, batch_idx: 60
# CLIP: 323828, pndm
# CLIP: 323895, pndm
# CLIP: 324158, pndm
# CLIP: 324258, pndm
# CLIP: 324614, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 324715, pndm
# CLIP: 324927, pndm
# CLIP: 325031, pndm
# CLIP: 325114, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 325306, pndm
# CLIP: 325347, pndm
# CLIP: 325483, pndm
# CLIP: 325527, pndm
# CLIP: 325838, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325991, pndm
# CLIP: 326082, pndm
# CLIP: 326128, pndm
# CLIP: 326174, pndm
# CLIP: 326248, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 326462, pndm
# CLIP: 326541, pndm
# CLIP: 326542, pndm
# CLIP: 326627, pndm
# CLIP: 326970, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327592, pndm
# CLIP: 327601, pndm
# CLIP: 327605, pndm
# CLIP: 327617, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 327701, pndm
# CLIP: 327769, pndm
# CLIP: 327780, pndm
# CLIP: 327890, pndm
# CLIP: 328030, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328117, pndm
# CLIP: 328238, pndm
# CLIP: 328286, pndm
# CLIP: 328337, pndm
# CLIP: 328430, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328683, pndm
# CLIP: 328959, pndm
# CLIP: 329041, pndm
# CLIP: 329080, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 329219, pndm
# CLIP: 329319, pndm
# CLIP: 329323, pndm
# CLIP: 329447, pndm
# CLIP: 329455, pndm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: pndm, batch_idx: 70
# CLIP: 329456, pndm
# CLIP: 329542, pndm
# CLIP: 329614, pndm
# CLIP: 329827, pndm
# CLIP: 330369, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 330396, pndm
# CLIP: 330554, pndm
# CLIP: 330790, pndm
# CLIP: 330818, pndm
# CLIP: 331075, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331280, pndm
# CLIP: 331352, pndm
# CLIP: 331569, pndm
# CLIP: 331604, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 331799, pndm
# CLIP: 331817, pndm
# CLIP: 332318, pndm
# CLIP: 332351, pndm
# CLIP: 332455, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 332570, pndm
# CLIP: 332845, pndm
# CLIP: 332901, pndm
# CLIP: 333069, pndm
# CLIP: 333237, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 333402, pndm
# CLIP: 333697, pndm
# CLIP: 333745, pndm
# CLIP: 333772, pndm
# CLIP: 333956, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334006, pndm
# CLIP: 334309, pndm
# CLIP: 334371, pndm
# CLIP: 334399, pndm
# CLIP: 334417, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334483, pndm
# CLIP: 334521, pndm
# CLIP: 334530, pndm
# CLIP: 334555, pndm
# CLIP: 334719, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334767, pndm
# CLIP: 334977, pndm
# CLIP: 335081, pndm
# CLIP: 335328, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 335427, pndm
# CLIP: 335450, pndm
# CLIP: 335529, pndm
# CLIP: 335658, pndm
# CLIP: 335800, pndm
# 	COMPUTED 5 CLIP SCORES
# scheduler name: pndm, batch_idx: 80
# CLIP: 335954, pndm
# CLIP: 336053, pndm
# CLIP: 336209, pndm
# CLIP: 336232, pndm
# CLIP: 336265, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 336309, pndm
# CLIP: 336356, pndm
# CLIP: 336628, pndm
# CLIP: 336658, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 337055, pndm
# CLIP: 337498, pndm
# CLIP: 337987, pndm
# CLIP: 338191, pndm
# CLIP: 338219, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338304, pndm
# CLIP: 338325, pndm
# CLIP: 338428, pndm
# CLIP: 338532, pndm
# CLIP: 338560, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338624, pndm
# CLIP: 338718, pndm
# 	COMPUTED 2 CLIP SCORES
# CLIP: 338986, pndm
# CLIP: 339442, pndm
# CLIP: 339823, pndm
# CLIP: 339870, pndm
# CLIP: 340015, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340175, pndm
# CLIP: 340272, pndm
# CLIP: 340451, pndm
# CLIP: 340697, pndm
# CLIP: 340894, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340930, pndm
# CLIP: 341094, pndm
# CLIP: 341196, pndm
# CLIP: 341469, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 341681, pndm
# CLIP: 341719, pndm
# CLIP: 341828, pndm
# CLIP: 341921, pndm
# CLIP: 341973, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 342006, pndm
# CLIP: 342128, pndm
# CLIP: 342186, pndm
# CLIP: 342367, pndm
# 	COMPUTED 4 CLIP SCORES
# scheduler name: pndm, batch_idx: 90
# CLIP: 342397, pndm
# CLIP: 342971, pndm
# CLIP: 343076, pndm
# CLIP: 343149, pndm
# CLIP: 343218, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343315, pndm
# CLIP: 343453, pndm
# CLIP: 343466, pndm
# CLIP: 343496, pndm
# CLIP: 343524, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343561, pndm
# CLIP: 343706, pndm
# CLIP: 343803, pndm
# CLIP: 343934, pndm
# CLIP: 343937, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343976, pndm
# CLIP: 344029, pndm
# CLIP: 344059, pndm
# CLIP: 344100, pndm
# CLIP: 344268, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344611, pndm
# CLIP: 344614, pndm
# CLIP: 344621, pndm
# CLIP: 344795, pndm
# CLIP: 344816, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344888, pndm
# CLIP: 344909, pndm
# CLIP: 345027, pndm
# CLIP: 345252, pndm
# CLIP: 345261, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345356, pndm
# CLIP: 345361, pndm
# CLIP: 345385, pndm
# CLIP: 345397, pndm
# CLIP: 345466, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345469, pndm
# CLIP: 345941, pndm
# CLIP: 346232, pndm
# CLIP: 346638, pndm
# CLIP: 346703, pndm
# 	COMPUTED 5 CLIP SCORES
# CLIP: 346905, pndm
# CLIP: 346968, pndm
# CLIP: 347163, pndm
# CLIP: 347174, pndm
# 	COMPUTED 4 CLIP SCORES
# CLIP: 347254, pndm
# CLIP: 347456, pndm
# 	COMPUTED 2 CLIP SCORES
# scheduler name: pndm, batch_idx: 100
# SCHEDULER: ddim
# CLIP: 289594, ddim
# CLIP: 289659, ddim
# CLIP: 289702, ddim
# CLIP: 289741, ddim
# CLIP: 289938, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 289960, ddim
# CLIP: 289992, ddim
# CLIP: 290081, ddim
# CLIP: 290163, ddim
# CLIP: 290179, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290248, ddim
# CLIP: 290293, ddim
# CLIP: 290592, ddim
# CLIP: 290619, ddim
# CLIP: 290768, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 290771, ddim
# CLIP: 290833, ddim
# CLIP: 290843, ddim
# CLIP: 291490, ddim
# CLIP: 291551, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 291619, ddim
# CLIP: 291634, ddim
# CLIP: 291664, ddim
# CLIP: 291791, ddim
# CLIP: 291861, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292005, ddim
# CLIP: 292024, ddim
# CLIP: 292060, ddim
# CLIP: 292082, ddim
# CLIP: 292155, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292225, ddim
# CLIP: 292236, ddim
# CLIP: 292330, ddim
# CLIP: 292415, ddim
# CLIP: 292446, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 292456, ddim
# CLIP: 292488, ddim
# CLIP: 292908, ddim
# CLIP: 292997, ddim
# CLIP: 293044, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293071, ddim
# CLIP: 293200, ddim
# CLIP: 293245, ddim
# CLIP: 293300, ddim
# CLIP: 293324, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 293474, ddim
# CLIP: 293625, ddim
# CLIP: 293794, ddim
# CLIP: 293804, ddim
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddim, batch_idx: 10
# CLIP: 293858, ddim
# CLIP: 294162, ddim
# CLIP: 294163, ddim
# CLIP: 294695, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 294783, ddim
# CLIP: 294831, ddim
# CLIP: 294855, ddim
# CLIP: 295138, ddim
# CLIP: 295231, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 295316, ddim
# CLIP: 295420, ddim
# CLIP: 295478, ddim
# CLIP: 295797, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 295809, ddim
# CLIP: 296222, ddim
# CLIP: 296224, ddim
# CLIP: 296231, ddim
# CLIP: 296284, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 296317, ddim
# CLIP: 296634, ddim
# ...
# CLIP: 297085, ddim
# CLIP: 297147, ddim
# CLIP: 297343, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297353, ddim
# CLIP: 297396, ddim
# CLIP: 297427, ddim
# CLIP: 297562, ddim
# CLIP: 297578, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 297595, ddim
# CLIP: 297681, ddim
# CLIP: 297698, ddim
# CLIP: 297830, ddim
# CLIP: 298251, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 298697, ddim
# CLIP: 298738, ddim
# CLIP: 298904, ddim
# CLIP: 298994, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 299355, ddim
# CLIP: 299553, ddim
# CLIP: 299609, ddim
# CLIP: 299720, ddim
# CLIP: 299887, ddim
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddim, batch_idx: 20
# CLIP: 300039, ddim
# CLIP: 300233, ddim
# CLIP: 300276, ddim
# CLIP: 300341, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 300659, ddim
# CLIP: 300842, ddim
# CLIP: 300913, ddim
# CLIP: 301061, ddim
# CLIP: 301135, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301376, ddim
# CLIP: 301421, ddim
# CLIP: 301563, ddim
# CLIP: 301718, ddim
# CLIP: 301867, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 301981, ddim
# CLIP: 302030, ddim
# CLIP: 302107, ddim
# CLIP: 302165, ddim
# CLIP: 302452, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 302536, ddim
# CLIP: 302760, ddim
# CLIP: 302882, ddim
# CLIP: 302990, ddim
# CLIP: 303305, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303499, ddim
# CLIP: 303566, ddim
# CLIP: 303653, ddim
# CLIP: 303713, ddim
# CLIP: 303818, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 303863, ddim
# CLIP: 303893, ddim
# CLIP: 303908, ddim
# CLIP: 304180, ddim
# CLIP: 304291, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 304365, ddim
# CLIP: 304404, ddim
# CLIP: 304545, ddim
# CLIP: 304560, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 304812, ddim
# CLIP: 304817, ddim
# CLIP: 304984, ddim
# CLIP: 305309, ddim
# CLIP: 305317, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 305343, ddim
# CLIP: 305609, ddim
# CLIP: 305695, ddim
# CLIP: 306136, ddim
# CLIP: 306139, ddim
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddim, batch_idx: 30
# CLIP: 306437, ddim
# CLIP: 306582, ddim
# CLIP: 306700, ddim
# CLIP: 306733, ddim
# CLIP: 306893, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 307145, ddim
# CLIP: 307172, ddim
# CLIP: 307658, ddim
# 	COMPUTED 3 CLIP SCORES
# CLIP: 308165, ddim
# CLIP: 308193, ddim
# CLIP: 308328, ddim
# CLIP: 308391, ddim
# CLIP: 308394, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 308466, ddim
# CLIP: 308476, ddim
# CLIP: 308531, ddim
# CLIP: 308545, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 308587, ddim
# CLIP: 308631, ddim
# CLIP: 308753, ddim
# CLIP: 308799, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309391, ddim
# CLIP: 309452, ddim
# CLIP: 309467, ddim
# CLIP: 309484, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 309495, ddim
# CLIP: 309655, ddim
# CLIP: 309678, ddim
# CLIP: 309938, ddim
# CLIP: 309964, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 310072, ddim
# CLIP: 310200, ddim
# CLIP: 310622, ddim
# CLIP: 310862, ddim
# CLIP: 310980, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 311002, ddim
# CLIP: 311081, ddim
# CLIP: 311180, ddim
# 	COMPUTED 3 CLIP SCORES
# CLIP: 311303, ddim
# CLIP: 311392, ddim
# CLIP: 311394, ddim
# CLIP: 311789, ddim
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddim, batch_idx: 40
# CLIP: 311883, ddim
# CLIP: 311928, ddim
# CLIP: 311950, ddim
# CLIP: 312192, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 312213, ddim
# CLIP: 312237, ddim
# CLIP: 312263, ddim
# CLIP: 312278, ddim
# CLIP: 312340, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312406, ddim
# CLIP: 312421, ddim
# CLIP: 312489, ddim
# CLIP: 312549, ddim
# CLIP: 312552, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 312720, ddim
# CLIP: 313130, ddim
# CLIP: 313182, ddim
# 	COMPUTED 3 CLIP SCORES
# CLIP: 313562, ddim
# CLIP: 313588, ddim
# CLIP: 314034, ddim
# 	COMPUTED 3 CLIP SCORES
# CLIP: 314177, ddim
# CLIP: 314182, ddim
# CLIP: 314251, ddim
# CLIP: 314264, ddim
# CLIP: 314294, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 314541, ddim
# CLIP: 314914, ddim
# CLIP: 315001, ddim
# CLIP: 315187, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 315219, ddim
# CLIP: 315257, ddim
# CLIP: 315450, ddim
# CLIP: 316015, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 316054, ddim
# CLIP: 316666, ddim
# CLIP: 317024, ddim
# CLIP: 317433, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 318080, ddim
# CLIP: 318114, ddim
# CLIP: 318138, ddim
# CLIP: 318238, ddim
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddim, batch_idx: 50
# CLIP: 318455, ddim
# CLIP: 318908, ddim
# CLIP: 319184, ddim
# CLIP: 319369, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 319534, ddim
# CLIP: 319607, ddim
# CLIP: 319617, ddim
# CLIP: 319696, ddim
# CLIP: 319721, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 319935, ddim
# CLIP: 320232, ddim
# CLIP: 320425, ddim
# CLIP: 320490, ddim
# CLIP: 320554, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 320632, ddim
# CLIP: 320664, ddim
# CLIP: 320696, ddim
# 	COMPUTED 3 CLIP SCORES
# CLIP: 320743, ddim
# CLIP: 321118, ddim
# CLIP: 321214, ddim
# CLIP: 321333, ddim
# CLIP: 321557, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 321790, ddim
# CLIP: 321887, ddim
# CLIP: 322163, ddim
# CLIP: 322211, ddim
# CLIP: 322352, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322429, ddim
# CLIP: 322574, ddim
# CLIP: 322610, ddim
# CLIP: 322724, ddim
# CLIP: 322829, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 322844, ddim
# CLIP: 322864, ddim
# CLIP: 322895, ddim
# CLIP: 322944, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 322968, ddim
# CLIP: 323151, ddim
# CLIP: 323202, ddim
# CLIP: 323263, ddim
# CLIP: 323355, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 323496, ddim
# CLIP: 323571, ddim
# CLIP: 323709, ddim
# CLIP: 323751, ddim
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddim, batch_idx: 60
# CLIP: 323828, ddim
# CLIP: 323895, ddim
# CLIP: 324158, ddim
# CLIP: 324258, ddim
# CLIP: 324614, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 324715, ddim
# CLIP: 324927, ddim
# CLIP: 325031, ddim
# CLIP: 325114, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 325306, ddim
# CLIP: 325347, ddim
# CLIP: 325483, ddim
# CLIP: 325527, ddim
# CLIP: 325838, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 325991, ddim
# CLIP: 326082, ddim
# CLIP: 326128, ddim
# CLIP: 326174, ddim
# CLIP: 326248, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 326462, ddim
# CLIP: 326541, ddim
# CLIP: 326542, ddim
# CLIP: 326627, ddim
# CLIP: 326970, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 327592, ddim
# CLIP: 327601, ddim
# CLIP: 327605, ddim
# CLIP: 327617, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 327701, ddim
# CLIP: 327769, ddim
# CLIP: 327780, ddim
# CLIP: 327890, ddim
# CLIP: 328030, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328117, ddim
# CLIP: 328238, ddim
# CLIP: 328286, ddim
# CLIP: 328337, ddim
# CLIP: 328430, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 328683, ddim
# CLIP: 328959, ddim
# CLIP: 329041, ddim
# CLIP: 329080, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 329219, ddim
# CLIP: 329319, ddim
# CLIP: 329323, ddim
# CLIP: 329447, ddim
# CLIP: 329455, ddim
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddim, batch_idx: 70
# CLIP: 329456, ddim
# CLIP: 329542, ddim
# CLIP: 329614, ddim
# CLIP: 329827, ddim
# CLIP: 330369, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 330396, ddim
# CLIP: 330554, ddim
# CLIP: 330790, ddim
# CLIP: 330818, ddim
# CLIP: 331075, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 331280, ddim
# CLIP: 331352, ddim
# CLIP: 331569, ddim
# CLIP: 331604, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 331799, ddim
# CLIP: 331817, ddim
# CLIP: 332318, ddim
# CLIP: 332351, ddim
# CLIP: 332455, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 332570, ddim
# CLIP: 332845, ddim
# CLIP: 332901, ddim
# CLIP: 333069, ddim
# CLIP: 333237, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 333402, ddim
# CLIP: 333697, ddim
# CLIP: 333745, ddim
# CLIP: 333772, ddim
# CLIP: 333956, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334006, ddim
# CLIP: 334309, ddim
# CLIP: 334371, ddim
# CLIP: 334399, ddim
# CLIP: 334417, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334483, ddim
# CLIP: 334521, ddim
# CLIP: 334530, ddim
# CLIP: 334555, ddim
# CLIP: 334719, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 334767, ddim
# CLIP: 334977, ddim
# CLIP: 335081, ddim
# CLIP: 335328, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 335427, ddim
# CLIP: 335450, ddim
# CLIP: 335529, ddim
# CLIP: 335658, ddim
# CLIP: 335800, ddim
# 	COMPUTED 5 CLIP SCORES
# scheduler name: ddim, batch_idx: 80
# CLIP: 335954, ddim
# CLIP: 336053, ddim
# CLIP: 336209, ddim
# CLIP: 336232, ddim
# CLIP: 336265, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 336309, ddim
# CLIP: 336356, ddim
# CLIP: 336628, ddim
# CLIP: 336658, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 337055, ddim
# CLIP: 337498, ddim
# CLIP: 337987, ddim
# CLIP: 338191, ddim
# CLIP: 338219, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338304, ddim
# CLIP: 338325, ddim
# CLIP: 338428, ddim
# CLIP: 338532, ddim
# CLIP: 338560, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 338624, ddim
# CLIP: 338718, ddim
# 	COMPUTED 2 CLIP SCORES
# CLIP: 338986, ddim
# CLIP: 339442, ddim
# CLIP: 339823, ddim
# CLIP: 339870, ddim
# CLIP: 340015, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340175, ddim
# CLIP: 340272, ddim
# CLIP: 340451, ddim
# CLIP: 340697, ddim
# CLIP: 340894, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 340930, ddim
# CLIP: 341094, ddim
# CLIP: 341196, ddim
# CLIP: 341469, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 341681, ddim
# CLIP: 341719, ddim
# CLIP: 341828, ddim
# CLIP: 341921, ddim
# CLIP: 341973, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 342006, ddim
# CLIP: 342128, ddim
# CLIP: 342186, ddim
# CLIP: 342367, ddim
# 	COMPUTED 4 CLIP SCORES
# scheduler name: ddim, batch_idx: 90
# CLIP: 342397, ddim
# CLIP: 342971, ddim
# CLIP: 343076, ddim
# CLIP: 343149, ddim
# CLIP: 343218, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343315, ddim
# CLIP: 343453, ddim
# CLIP: 343466, ddim
# CLIP: 343496, ddim
# CLIP: 343524, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343561, ddim
# CLIP: 343706, ddim
# CLIP: 343803, ddim
# CLIP: 343934, ddim
# CLIP: 343937, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 343976, ddim
# CLIP: 344029, ddim
# CLIP: 344059, ddim
# CLIP: 344100, ddim
# CLIP: 344268, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344611, ddim
# CLIP: 344614, ddim
# CLIP: 344621, ddim
# CLIP: 344795, ddim
# CLIP: 344816, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 344888, ddim
# CLIP: 344909, ddim
# CLIP: 345027, ddim
# CLIP: 345252, ddim
# CLIP: 345261, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345356, ddim
# CLIP: 345361, ddim
# CLIP: 345385, ddim
# CLIP: 345397, ddim
# CLIP: 345466, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 345469, ddim
# CLIP: 345941, ddim
# CLIP: 346232, ddim
# CLIP: 346638, ddim
# CLIP: 346703, ddim
# 	COMPUTED 5 CLIP SCORES
# CLIP: 346905, ddim
# CLIP: 346968, ddim
# CLIP: 347163, ddim
# CLIP: 347174, ddim
# 	COMPUTED 4 CLIP SCORES
# CLIP: 347254, ddim
# CLIP: 347456, ddim
# 	COMPUTED 2 CLIP SCORES
# scheduler name: ddim, batch_idx: 100
# SCHEDULER: unipc
# SCHEDULER: lms
# CLIP: 289741, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 290293, lms
# CLIP: 290592, lms
# CLIP: 290768, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 290771, lms
# CLIP: 291551, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 291664, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 292024, lms
# CLIP: 292155, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 292236, lms
# CLIP: 292330, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 292456, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 293071, lms
# CLIP: 293300, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 293625, lms
# CLIP: 293794, lms
# CLIP: 293804, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 293858, lms
# CLIP: 294163, lms
# 	COMPUTED 2 CLIP SCORES
# scheduler name: lms, batch_idx: 10
# CLIP: 295138, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 295478, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 295809, lms
# CLIP: 296224, lms
# CLIP: 296284, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 296317, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 297022, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 297562, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 297681, lms
# CLIP: 297830, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 298697, lms
# CLIP: 298994, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 299887, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 300233, lms
# 	COMPUTED 1 CLIP SCORES
# scheduler name: lms, batch_idx: 20
# CLIP: 300659, lms
# CLIP: 301061, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 301376, lms
# CLIP: 301718, lms
# CLIP: 301867, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 301981, lms
# CLIP: 302107, lms
# CLIP: 302165, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 302760, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 303499, lms
# CLIP: 303818, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 304180, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 304365, lms
# CLIP: 304545, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 304812, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 306582, lms
# CLIP: 306700, lms
# CLIP: 306893, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 307658, lms
# 	COMPUTED 1 CLIP SCORES
# scheduler name: lms, batch_idx: 30
# CLIP: 308165, lms
# CLIP: 308193, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 308531, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 308587, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 309391, lms
# CLIP: 309467, lms
# CLIP: 309484, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 309495, lms
# CLIP: 309655, lms
# CLIP: 309938, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 310200, lms
# CLIP: 310622, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 311002, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 311392, lms
# CLIP: 311394, lms
# CLIP: 311789, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 311950, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 312213, lms
# CLIP: 312263, lms
# CLIP: 312340, lms
# 	COMPUTED 3 CLIP SCORES
# scheduler name: lms, batch_idx: 40
# CLIP: 312489, lms
# CLIP: 312552, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 312720, lms
# CLIP: 313130, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 313562, lms
# CLIP: 313588, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 314177, lms
# CLIP: 314182, lms
# CLIP: 314251, lms
# CLIP: 314264, lms
# 	COMPUTED 4 CLIP SCORES
# CLIP: 314914, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 315219, lms
# CLIP: 315450, lms
# CLIP: 316015, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 316054, lms
# CLIP: 316666, lms
# CLIP: 317433, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 318080, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 318908, lms
# CLIP: 319369, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 319696, lms
# CLIP: 319721, lms
# 	COMPUTED 2 CLIP SCORES
# scheduler name: lms, batch_idx: 50
# CLIP: 320632, lms
# CLIP: 320664, lms
# CLIP: 320696, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 321118, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 321887, lms
# CLIP: 322352, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 322429, lms
# CLIP: 322574, lms
# CLIP: 322829, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 322844, lms
# CLIP: 322944, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 323202, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 323751, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 324158, lms
# CLIP: 324614, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 324927, lms
# CLIP: 325114, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 325306, lms
# CLIP: 325347, lms
# CLIP: 325483, lms
# CLIP: 325527, lms
# 	COMPUTED 4 CLIP SCORES
# scheduler name: lms, batch_idx: 60
# CLIP: 326128, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 326462, lms
# CLIP: 326541, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 327592, lms
# CLIP: 327601, lms
# CLIP: 327617, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 327701, lms
# CLIP: 327769, lms
# CLIP: 328030, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 328117, lms
# CLIP: 328238, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 329080, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 329219, lms
# CLIP: 329447, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 329456, lms
# CLIP: 330369, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 330396, lms
# CLIP: 330554, lms
# CLIP: 330790, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 331352, lms
# CLIP: 331569, lms
# CLIP: 331604, lms
# 	COMPUTED 3 CLIP SCORES
# scheduler name: lms, batch_idx: 70
# CLIP: 331817, lms
# CLIP: 332318, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 333069, lms
# CLIP: 333237, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 333402, lms
# CLIP: 333745, lms
# CLIP: 333772, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 334483, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 336265, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 336356, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 337055, lms
# CLIP: 337987, lms
# CLIP: 338191, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 338304, lms
# CLIP: 338325, lms
# CLIP: 338532, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 338624, lms
# CLIP: 338718, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 338986, lms
# CLIP: 339823, lms
# CLIP: 340015, lms
# 	COMPUTED 3 CLIP SCORES
# scheduler name: lms, batch_idx: 80
# CLIP: 340451, lms
# CLIP: 340894, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 341094, lms
# CLIP: 341469, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 341719, lms
# CLIP: 341921, lms
# CLIP: 341973, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 342128, lms
# CLIP: 342367, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 342397, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 343453, lms
# CLIP: 343466, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 343803, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 343976, lms
# CLIP: 344100, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 344795, lms
# CLIP: 344816, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 344888, lms
# CLIP: 345261, lms
# 	COMPUTED 2 CLIP SCORES
# scheduler name: lms, batch_idx: 90
# CLIP: 345356, lms
# CLIP: 345397, lms
# CLIP: 345466, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 345941, lms
# CLIP: 346638, lms
# CLIP: 346703, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 346905, lms
# CLIP: 347174, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 347254, lms
# CLIP: 347456, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 348012, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 348216, lms
# CLIP: 348243, lms
# CLIP: 348481, lms
# 	COMPUTED 3 CLIP SCORES
# CLIP: 348708, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 349678, lms
# CLIP: 349837, lms
# 	COMPUTED 2 CLIP SCORES
# CLIP: 350023, lms
# 	COMPUTED 1 CLIP SCORES
# CLIP: 350388, lms
# CLIP: 350405, lms
# 	COMPUTED 2 CLIP SCORES
# scheduler name: lms, batch_idx: 100
# SCHEDULER: edm

# %% [markdown]
# - Number of total generated images by scheduler.
# - Images Generated have uniform sizing of (512x512)

# %%
images_generated = {s:0 for s in SCHEDULER_LABELS}

for s in SCHEDULER_LABELS:
    dir = GENERATED_COCO_DIR + f'/{s}'

    os.makedirs(dir, exist_ok=True)

    c = count_images(dir, output=False)
    print(f'{s}: \t {c}')

    if c > COCO_MIN_IMAGE_COUNT:
        images_generated[s] = c
# Out:
# ddpm: 	 5000
# pndm: 	 5000
# ddim: 	 5000
# unipc: 	 5000
# lms: 	 5000
# heun: 	 4998
# eds: 	 4980
# edm: 	 5000

# %% [markdown]
# ### FID scores

# %%
from torchvision import models
import torch.nn as nn

incept_model = models.inception_v3(weights=INCEPT_WEIGHTS, transform_input=False)
# remove classifier
incept_model.fc = nn.Identity()
# disable aux branch
incept_model.aux_logits = False
incept_model.eval().cuda()

generated_image_paths={}
labels = [x for x in schedulers.keys()]


if os.path.exists(FID_PATH) and os.path.getsize(FID_PATH) > 0:
    fid_scores_df = pd.read_csv(FID_PATH)
else:
    # If the file doesn't exist or is empty, create an empty DataFrame with headers
    # Save the empty DataFrame with headers to the file
    pd.DataFrame(columns=['scheduler', 'fid_score']).to_csv(FID_PATH, index=False)


    fid_scores_df = pd.read_csv(FID_PATH)

mu_real, sigma_real = get_real_tensors(incept_model)


# incept_model = models.inception_v3(pretrained=True, aux_logits=True)
# incept_model.fc = nn.Identity()
# incept_model.aux_logits = False
# incept_model.eval().to(torch.device("cuda"))

fid_scores = {}
for s in labels:
    if s in fid_scores_df['scheduler'].values:
        print(f'already computed {s}')
        continue

    s_dir = f'{GENERATED_COCO_DIR}/{s}'
    paths = [
        os.path.join(s_dir,f) for f in os.listdir(s_dir)
        if os.path.isfile(os.path.join(s_dir, f))
    ]

    mu_gen, sigma_gen = compute_stats(paths, incept_model, device="cuda", batch_size=32)
    fid_scores[s] = frechet_distance(mu_gen, sigma_gen, mu_real, sigma_real)
    print(f'FID score for {s}: {fid_scores[s]}')
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 215MB/s]
# Streaming output truncated to the last 5000 lines.
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/330818.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/331075.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334006.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334309.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334371.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334399.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334417.png
# i: 160, batch: 5
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334483.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334521.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334530.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334555.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334719.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334767.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/334977.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335081.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335328.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335427.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335450.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335529.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335658.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335800.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/335954.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/336053.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/336209.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/336232.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/336265.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/83113.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/83172.png
# i: 4992, batch: 156
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/83531.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/83540.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84031.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84170.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84241.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84270.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84362.png
# 	 p: /content/drive/MyDrive/Research299/COCO/generated/edm/84431.png
# FID score for edm: 465.3114013671875

# %%
fid_scores
# Out:
# {'eds': 26.784271240234375,
#  'heun': 26.48236083984375,
#  'ddpm': 29.48480224609375,
#  'pndm': 25.57440185546875,
#  'ddim': 25.384002685546875,
#  'unipc': 27.526885986328125,
#  'lms': 26.584686279296875,
#  'edm': 465.3114013671875}

# %% [markdown]
# ### CLIP data

# %%
clip_df = pd.read_csv(CLIP_PATH)
print(clip_df.shape)
unique_df = clip_df.drop_duplicates(subset=["image_id", "scheduler"], keep="first")
unique_df.shape
# Out:
# (36954, 3)
# (36924, 3)

# %%
labels = [x for x in schedulers.keys()]
count = 0
for s in labels:
    instances = unique_df.loc[unique_df['scheduler'] == s].shape[0]
    print(f'{s}: {unique_df.loc[unique_df['scheduler'] == s].shape}')
    count += instances
print(f'total: {count}')
# Out:
# eds: (3999, 3)
# heun: (4055, 3)
# ddpm: (4953, 3)
# pndm: (4474, 3)
# ddim: (4454, 3)
# unipc: (5000, 3)
# lms: (4989, 3)
# edm: (5000, 3)
# total: 36924

# %%
for s in labels:
    print(s)
    print(unique_df.loc[unique_df['scheduler'] == s].describe())
# Out:
# eds
#             image_id   clip_score
# count    3999.000000  3999.000000
# mean   259527.938235    31.254709
# std    173864.742494     2.903805
# min       139.000000    18.849606
# 25%    119299.000000    29.369969
# 50%    229747.000000    31.177143
# 75%    347413.000000    33.139845
# max    581781.000000    42.946587
# heun
#             image_id   clip_score
# count    4055.000000  4055.000000
# mean   261207.523798    31.296409
# std    173260.675079     2.872615
# min       139.000000    19.663206
# 25%    120942.000000    29.366270
# 50%    232244.000000    31.240030
# 75%    400187.500000    33.180149
# max    581781.000000    41.941254
# ddpm
#             image_id   clip_score
# count    4953.000000  4953.000000
# mean   288932.948718    31.277321
# std    168279.039432     2.924710
# min       139.000000    18.752663
# 25%    146489.000000    29.373322
# 50%    287545.000000    31.259928
# 75%    437239.000000    33.150562
# max    581781.000000    43.509571
# pndm
#             image_id   clip_score
# count    4474.000000  4474.000000
# mean   272842.313813    31.253676
# std    168986.834206     2.892122
# min       139.000000    18.312958
# 25%    132169.250000    29.366997
# 50%    258838.000000    31.234801
# 75%    402069.750000    33.214156
# max    581781.000000    44.033562
# ddim
#             image_id   clip_score
# count    4454.000000  4454.000000
# mean   272336.151998    31.242328
# std    169192.486607     2.851137
# min       139.000000    18.490944
# 25%    131397.250000    29.329315
# 50%    257126.500000    31.220998
# 75%    402354.250000    33.071016
# max    581781.000000    42.813469
# unipc
#             image_id   clip_score
# count    5000.000000  5000.000000
# mean   289562.336600    31.166217
# std    167613.417537     2.997288
# min       139.000000    17.249783
# 25%    147728.000000    29.229426
# 50%    289590.000000    31.143884
# 75%    435205.250000    33.100197
# max    581781.000000    42.070309
# lms
#             image_id   clip_score
# count    4989.000000  4989.000000
# mean   289407.542794    31.138849
# std    167765.162440     2.959689
# min       139.000000    18.881851
# 25%    147498.000000    29.268610
# 50%    289343.000000    31.091225
# 75%    435299.000000    33.091957
# max    581781.000000    42.147717
# edm
#             image_id   clip_score
# count    5000.000000  5000.000000
# mean   289562.336600    21.195693
# std    167613.417537     2.120885
# min       139.000000    10.196809
# 25%    147728.000000    19.999360
# 50%    289590.000000    21.441475
# 75%    435205.250000    22.651834
# max    581781.000000    26.978075

# %% [markdown]
# ## Results

# %% [markdown]
# ### Histograms of clip Scores

# %% [markdown]
# #### by scheduler

# %%
import matplotlib.pyplot as plt
clip_df = pd.read_csv(CLIP_PATH)
for scheduler, g in clip_df.groupby('scheduler'):
    plt.figure()
    plt.hist(g['clip_score'], bins=30)
    plt.title(f'CLIP Score Histogram — {scheduler}')
    plt.xlabel('CLIP Score')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# #### Overlays

# %% [markdown]
# ##### All schedulers

# %% [markdown]
# ##### EDM underperforms
#
#     - Early steps remove structure-level noise.
#     - Later steps focus on fine details.
#     - Takes large denoising steps when noise is high.
#     - Uses Euler/Heun solvers like an ODE.

# %%
df = clip_df.copy()
N = min(df['scheduler'].value_counts())
plt.figure()
for scheduler, g in df.groupby('scheduler'):
    g_equalized = g.sample(n=N, random_state=42)
    plt.hist(g_equalized['clip_score'], bins=30, alpha=0.5, label=scheduler)

plt.legend()
plt.xlabel('CLIP Score')
plt.ylabel('Count')
plt.title('CLIP Score Histograms by Scheduler')
plt.show()

# %% [markdown]
# ##### ddim and ddpm

# %%
N = min(df['scheduler'].value_counts())
selected_schedulers = ['ddpm', 'ddim']
plt.figure()
for scheduler, g in df.groupby('scheduler'):
    if scheduler not in selected_schedulers: continue
    g_equalized = g.sample(n=N, random_state=42)
    plt.hist(g_equalized['clip_score'], bins=30, alpha=0.3, label=scheduler)

plt.legend()
plt.xlabel('CLIP Score')
plt.ylabel('Count')
plt.title('CLIP Score Histograms by Scheduler')
plt.show()

# %% [markdown]
# ##### Density

# %%
plt.figure()
for scheduler, g in df.groupby("scheduler"):
    plt.hist(
        g["clip_score"],
        bins=30,
        density=True,
        alpha=0.4,
        label=scheduler
    )

plt.xlabel("CLIP Score")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# ##### KDE

# %%
import numpy as np

plt.figure()
for scheduler, g in df.groupby("scheduler"):
    plt.hist(g["clip_score"], bins=30, density=True, alpha=0.2)
    g["clip_score"].plot(kind="kde", label=scheduler)

plt.xlabel("CLIP Score")
plt.ylabel("Density")
plt.legend()
plt.show()
